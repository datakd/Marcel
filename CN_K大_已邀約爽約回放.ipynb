# %%
from sqlalchemy import create_engine
import pandas as pd
import json
import requests
import os
import time
from glob import glob
import threading
from datetime import datetime, timedelta
from concurrent.futures import ThreadPoolExecutor
import random
import numpy as np

# %%
# 取得 Token , 設置請求參數 (大陸)
url = "https://login.xiaoshouyi.com/auc/oauth2/token"
headers = {
    "Content-Type": "application/x-www-form-urlencoded"
}
data = {
    "grant_type": "password",
    "client_id": "473f31e3a6cb9cafaec3ddf36d20092b",
    "client_secret": "ddfed65f5aeebacd0f54eaa464fcb043",
    "redirect_uri": "https://api-scrm.xiaoshouyi.com/",
    "username": "11021041@twkd.com",
    "password": "Marcellin01oiH88cCI"
}

# 發送 post 請求
response = requests.post(url, headers=headers, data=data)

if response.status_code == 200:
    print(response.json())
else:
    print("請求失敗, 狀態碼:", response.status_code)

content = response.json()
ac_token = content["access_token"]


print(ac_token)
# Out:
# {'access_token': '37d799146808f0f83657e0e90fb62f8e13595e783e68b7ebae8a2ad891976127.MjM2OTI2Njk5ODU2MzExMw==0', 'token_type': 'Bearer', 'expires_in': 86399, 'scope': 'all prm crm', 'tenant_id': '2369266998563113', 'login_type': '', 'encryption_key': '', 'client_id': '473f31e3a6cb9cafaec3ddf36d20092b', 'passport_id': '3052172005298442', 'mobile_params': '', 'instance_uri': 'api-scrm.xiaoshouyi.com'}
# 37d799146808f0f83657e0e90fb62f8e13595e783e68b7ebae8a2ad891976127.MjM2OTI2Njk5ODU2MzExMw==0

# %%
'''
select from user
'''
url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/query/xoqlScroll"
headers = {
    "Authorization": f"Bearer {ac_token}",
    "Content-Type":"application/x-www-form-urlencoded"
} 
data = {
    "xoql": "select id, name, dimDepart from user",
    #"xoql": "insert into contact(contactName, phone, email) values('貴夫人', '0912345678', 'kkdd@gmail.com')"
    "batchCount": 2000
}
response2 = requests.post(url_2, headers=headers, data = data)
ownerId = response2.json()
print(ownerId)
user_df = pd.json_normalize(ownerId["data"]["records"])  
# user_df[user_df['name']=='袁芳']
# Out:
# {'code': '200', 'msg': '', 'errorInfo': None, 'debugInfo': None, 'data': {'totalSize': 629, 'count': 629, 'records': [{'id': '2369301140133416', 'name': 'CRM管理员', 'dimDepart': '2586653553808230'}, {'id': '2508839248500196', 'name': '谢敏', 'dimDepart': '2369301140133408'}, {'id': '2508849255192015', 'name': '唐雪梅', 'dimDepart': '2746547845976859'}, {'id': '2531364166931931', 'name': '俞丽', 'dimDepart': '2369301140133408'}, {'id': '2531364279604701', 'name': '宋冀泽', 'dimDepart': '2369301140133408'}, {'id': '2586658357285641', 'name': '徐玮珍', 'dimDepart': '2586637755765606'}, {'id': '2586659192656747', 'name': '杨卫卫', 'dimDepart': '2586653553808212'}, {'id': '2586660964537152', 'name': '金海洋', 'dimDepart': '2586653553808230'}, {'id': '2586661145334617', 'name': '教育训练', 'dimDepart': '2746546870686577'}, {'id': '2586661881402202', 'name': '蔡家维', 'dimDepart': '2369301140133408'}, {'id': '2586663184339728', 'name': '刘俐君', 'dimDepart': '2586649840522022'}, {'id': '2586670417466176', 'name': '马梦文', 'dimDepart': '3418961396667154'}, {'id': '2586670520013616', 'name': '黄燕龙', 'dimDep
# %%
# from datetime import datetime

# # Unix 时间戳（以毫秒为单位）
# timestamp_ms = 1708444800000

# # 将毫秒转换为秒
# timestamp_s = timestamp_ms / 1000

# # 使用 datetime.fromtimestamp() 方法将 Unix 时间戳转换为日期
# date = datetime.fromtimestamp(timestamp_s)

# print(date)

# %%
# from datetime import datetime

# # 输入日期
# date_string = "2024-03-06"
# date_format = "%Y-%m-%d"

# # 将日期字符串解析为 datetime 对象
# date = datetime.strptime(date_string, date_format)

# # 将 datetime 对象转换为 Unix 时间戳（以毫秒为单位）
# timestamp_ms = int(date.timestamp() * 1000)

# print(timestamp_ms)

# %%
# '''
# select from Tasks withdraw 
# 將超過期望完成日七天的K大電訪交辦撤回重新提交
# '''
# url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/query/xoqlScroll"
# headers = {
#     "Authorization": f"Bearer {ac_token}",
#     "Content-Type":"application/x-www-form-urlencoded"
# }
# queryLocator = ''
# Tasks_df = pd.DataFrame()

# date_to_convert = datetime(2024, 3, 19) #設定日期
# timestamp = int(date_to_convert.timestamp() * 1000)

# while True:
#     data = {
#         "xoql": f'''
#         SELECT 
#         id,
#         name,
#         customItem10__c, 
#         customItem3__c,
#         customItem8__c,
#         customItem1__c 邀約日期, 
#         customItem58__c,
#         customItem50__c, 
#         customItem42__c, 
#         entityType,
#         dimDepart,
#         dimDepart.departName 區域,
#         approvalStatus,
#         customItem11__c
#         FROM 
#             customEntity14__c
#         WHERE 
#             entityType = '3074631761565155' 
#         AND 
#             customItem1__c >= {timestamp}
#         AND
#             customItem10__c = '3147232434771494'
#         ''',
#         "batchCount": 2000,
#         "queryLocator": queryLocator
#     }
#     response = requests.post(url_2, headers=headers, data=data)
#     crm = response.json()
#     data = pd.DataFrame(crm["data"]["records"])
#     Tasks_df = pd.concat([Tasks_df, data], ignore_index=True, sort=False)
    
#     if not crm['queryLocator']:
#         break
#     queryLocator = crm['queryLocator']

# Tasks_df['approvalStatus'] = Tasks_df['approvalStatus'].astype(str)
# Tasks_df['customItem8__c'] = Tasks_df['customItem8__c'].astype(str)
# Tasks_df['customItem3__c'] = Tasks_df['customItem3__c'].astype(str)

# Tasks_df['邀約日期'] = Tasks_df['邀約日期'].astype(float)
# Tasks_df['邀約日期'] = Tasks_df['邀約日期'].apply(lambda x: pd.to_datetime(x / 1000.0, unit='s', utc=True))
# Tasks_df['邀約日期'] = Tasks_df['邀約日期'].dt.tz_convert('Asia/Taipei')
# Tasks_df['邀約日期'] = Tasks_df['邀約日期'].dt.strftime('%Y-%m-%d')
# Tasks_df['邀約日期'] = pd.to_datetime(Tasks_df['邀約日期'], errors='coerce').dt.date

# Tasks_df = Tasks_df.loc[~Tasks_df['customItem3__c'].isin(["未接听"])] 
# Tasks_df = Tasks_df.loc[~Tasks_df['customItem3__c'].isin(["K大-客户未上线"])] 
# Tasks_df = Tasks_df[~Tasks_df['approvalStatus'].str.contains('审批通过')]
# Tasks_df

# %%
'''
select from Tasks withdraw 
將超過期望完成日七天的K大電訪交辦撤回重新提交
'''
url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/query/xoqlScroll"
headers = {
    "Authorization": f"Bearer {ac_token}",
    "Content-Type":"application/x-www-form-urlencoded"
}
queryLocator = ''
Tasks_df = pd.DataFrame()

date_to_convert = datetime(2024, 3, 19) #設定日期
timestamp = int(date_to_convert.timestamp() * 1000)

while True:
    data = {
        "xoql": f'''
        SELECT 
        id,
        name,
        customItem10__c, 
        customItem3__c,
        customItem8__c,
        customItem1__c 邀約日期, 
        customItem58__c,
        customItem50__c, 
        customItem42__c, 
        entityType,
        dimDepart,
        dimDepart.departName 區域,
        approvalStatus,
        customItem11__c
        FROM 
            customEntity14__c
        WHERE 
            entityType = '3074631761565155'
        AND
            customItem42__c != 2835550546744850
        AND 
            customItem1__c >= {timestamp}
        ''',
        "batchCount": 2000,
        "queryLocator": queryLocator
    }
    response = requests.post(url_2, headers=headers, data=data)
    crm = response.json()
    data = pd.DataFrame(crm["data"]["records"])
    Tasks_df = pd.concat([Tasks_df, data], ignore_index=True, sort=False)
    
    if not crm['queryLocator']:
        break
    queryLocator = crm['queryLocator']

Tasks_df['customItem8__c']= Tasks_df['customItem8__c'].astype(str)
Tasks_df = Tasks_df.loc[Tasks_df['customItem8__c'].str.contains("等待")]  

Tasks_df['邀約日期'] = Tasks_df['邀約日期'].astype(float)
Tasks_df['邀約日期'] = Tasks_df['邀約日期'].apply(lambda x: pd.to_datetime(x / 1000.0, unit='s', utc=True))
Tasks_df['邀約日期'] = Tasks_df['邀約日期'].dt.tz_convert('Asia/Taipei')
Tasks_df['邀約日期'] = Tasks_df['邀約日期'].dt.strftime('%Y-%m-%d')
Tasks_df['邀約日期'] = pd.to_datetime(Tasks_df['邀約日期'], errors='coerce').dt.date

Tasks_df['customItem58__c'] = Tasks_df['customItem58__c'].astype(str)
Tasks_df['customItem3__c'] = Tasks_df['customItem3__c'].astype(str)
# Tasks_df['customItem115__c'] = '1' # 業務行為設定為"電訪"

# 已邀但時間未定
Tasks_df2 = Tasks_df.loc[Tasks_df['customItem58__c'].str.contains("已邀") | Tasks_df['customItem3__c'].str.contains("已邀")] 
Tasks_df2 = Tasks_df2.loc[~(Tasks_df2['customItem58__c'].str.contains("业管课广发") | Tasks_df2['customItem3__c'].str.contains("业管课广发") | Tasks_df2['customItem3__c'].str.contains("广发型录"))] 

# 爽約
Tasks_df3 = Tasks_df.loc[Tasks_df['customItem3__c'].isin(["K大-客户未上线", "K大-客户末上线"])]
# Tasks_df3 = Tasks_df3.loc[~(Tasks_df3['customItem58__c'].str.contains("已邀"))]

# 未接聽
Tasks_df4 = Tasks_df.loc[Tasks_df['customItem3__c'].isin(["未接听"])] 
# Tasks_df4 = Tasks_df4.loc[~(Tasks_df3['customItem3__c'].str.contains("已邀"))]

today = datetime.now().date()

# %%
'''
select from Sales list K大顧問暨電訪人員名單
'''
url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/query/xoqlScroll"
headers = {
    "Authorization": f"Bearer {ac_token}",
    "Content-Type":"application/x-www-form-urlencoded"
}
queryLocator = ''
Sales_list = pd.DataFrame()

while True:
    data = {
        "xoql": '''
        SELECT 
        customItem2__c 电访人员, 
        customItem4__c 预估通数, 
        customItem3__c 电访人员类型
        FROM 
            customEntity47__c
        ''',
        "batchCount": 2000,
        "queryLocator": queryLocator
    }
    response = requests.post(url_2, headers=headers, data=data)
    crm = response.json()
    data = pd.DataFrame(crm["data"]["records"])
    Sales_list = pd.concat([Sales_list, data], ignore_index=True, sort=False)
    
    if not crm['queryLocator']:
        break
    queryLocator = crm['queryLocator']

Sales_list['电访人员类型']= Sales_list['电访人员类型'].astype(str)
Sales_list = Sales_list[Sales_list['预估通数']!='']
Sales_list['预估通数']= Sales_list['预估通数'].astype(int)
Sales_list = pd.merge(Sales_list, user_df, left_on = '电访人员', right_on = 'id', how = 'left')
Sales_list = Sales_list[Sales_list['预估通数']>0]
Sales_list1 = Sales_list.loc[~Sales_list['电访人员类型'].str.contains("产品顾问")]
# Sales_list1 = Sales_list1.loc[~Sales_list1['name'].isin(['黃祿庭', '陳鵬宇', '周淑真', '葉子瑄', '黃詩婷', '林育君'])] # 4/11智齒人員

# %%
## 已邀約

# # 將今天的日期減去7天
# seven_days_ago = today - timedelta(days=7)

# # 選擇邀約日期早於七天前的行
# Tasks_df2 = Tasks_df2[Tasks_df2['邀約日期'] < seven_days_ago]

Tasks_df2 = Tasks_df2[Tasks_df2['邀約日期'] < today]

Tasks_df2['电访人员'] = np.random.choice(Sales_list1['电访人员'], size=len(Tasks_df2))
Tasks_df2 = pd.merge(Tasks_df2, user_df, left_on = '电访人员', right_on = 'name', how = 'left')
Tasks_df2 = Tasks_df2.drop(['customItem10__c'],axis=1)
Tasks_df2 = Tasks_df2.rename(columns={'dimDepart_x':'dimDepart','电访人员':'customItem10__c', 'id_x':'id', 'name_x':'name'})
Tasks_df2['customItem1__c'] = today
Tasks_df2 = Tasks_df2.drop_duplicates(subset=['customItem42__c'], keep='last')

Tasks_df2
# Out:
# Empty DataFrame
# Columns: [id, name, customItem3__c, customItem8__c, 邀約日期, customItem58__c, customItem50__c, customItem42__c, entityType, dimDepart, 區域, approvalStatus, customItem11__c, customItem10__c, id_y, name_y, dimDepart_y, customItem1__c]
# Index: []

# %%
## K大爽約
# Tasks_df3 = Tasks_df3[Tasks_df3['邀約日期'] < seven_days_ago]
Tasks_df3 = Tasks_df3[Tasks_df3['邀約日期'] < today]
Tasks_df3['customItem1__c'] = today

Tasks_df3
# Out:
# Empty DataFrame
# Columns: [id, name, customItem10__c, customItem3__c, customItem8__c, 邀約日期, customItem58__c, customItem50__c, customItem42__c, entityType, dimDepart, 區域, approvalStatus, customItem11__c, customItem1__c]
# Index: []

# %%
# ## 未接聽
# Tasks_df4 = Tasks_df4[Tasks_df4['邀約日期'] < today]

# Tasks_df4['电访人员'] = np.random.choice(Sales_list1['电访人员'], size=len(Tasks_df4))
# Tasks_df4 = pd.merge(Tasks_df4, user_df, left_on = '电访人员', right_on = 'name', how = 'left')
# Tasks_df4 = Tasks_df4.drop(['customItem10__c'],axis=1)
# Tasks_df4 = Tasks_df4.rename(columns={'dimDepart_x':'dimDepart','电访人员':'customItem10__c', 'id_x':'id', 'name_x':'name'})
# Tasks_df4['customItem1__c'] = today
# Tasks_df4 = Tasks_df4.drop_duplicates(subset=['customItem42__c'], keep='last')

# Tasks_df4

# %%
# # Tasks_df4 = Tasks_df4[~Tasks_df4['approvalStatus'].str.contains("撤回")] 
# Tasks_df4['approvalStatus'] = Tasks_df4['approvalStatus'].astype(str)
# Tasks_df4 = Tasks_df4.loc[~(Tasks_df4['approvalStatus'].str.contains("撤回"))]
# Tasks_df4

# %%
'''
from K大預約表
'''

url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/query/xoqlScroll"
headers = {
    "Authorization": f"Bearer {ac_token}",
    "Content-Type":"application/x-www-form-urlencoded"
}
queryLocator = ''
K_visit_df = pd.DataFrame()
 
while True:
    data = {
        "xoql": '''
        SELECT 
        name,
        customItem6__c 联系人, 
        customItem2__c 预约日期, 
        customItem40__c, 
        customItem9__c 联系人手机号
        FROM customEntity26__c
        ''',
        "batchCount": 2000,
        "queryLocator": queryLocator
    }
    response = requests.post(url_2, headers=headers, data=data)
    crm = response.json()
    data = pd.DataFrame(crm["data"]["records"])
    K_visit_df = pd.concat([K_visit_df, data], ignore_index=True, sort=False)
    
    if not crm['queryLocator']:
        break
    queryLocator = crm['queryLocator']

# 5/27 美耐板K大開始
K_visit_df['预约日期'] = pd.to_datetime(K_visit_df['预约日期'], unit='ms').dt.tz_localize('UTC').dt.tz_convert('Asia/Taipei')
start_date = pd.Timestamp('2024-05-27', tz='UTC')
K_visit_df['预约日期'] = pd.to_datetime(K_visit_df['预约日期'])
K_visit_df = K_visit_df[K_visit_df['预约日期'] >= start_date]

# 有舉行K大
K_visit_df['customItem40__c'] = K_visit_df['customItem40__c'].astype(str)
K_visit_df_held = K_visit_df[K_visit_df['customItem40__c'].str.contains("是")]

# 未來場次
today_date = datetime.now().strftime('%Y-%m-%d')
K_visit_df_future = K_visit_df[K_visit_df['预约日期'] >= today_date]

K_visit_df = pd.concat([K_visit_df_held, K_visit_df_future])
# Out:
# C:\Users\11021041\AppData\Local\Temp\ipykernel_9288\2172204724.py:37: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   K_visit_df['预约日期'] = pd.to_datetime(K_visit_df['预约日期'], unit='ms').dt.tz_localize('UTC').dt.tz_convert('Asia/Taipei')

# %%
'''
from K大預約参會人
'''
url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/query/xoqlScroll"
headers = {
    "Authorization": f"Bearer {ac_token}",
    "Content-Type":"application/x-www-form-urlencoded"
}
queryLocator = ''
K_visit_df_attendant = pd.DataFrame()
 
while True:
    data = {
        "xoql": '''
        select 
        name,
        customItem1__c K大预约表编号,
        customItem2__c 联系人, 
        customItem5__c 联系人手机号
        from customEntity27__c
        ''',
        "batchCount": 2000,
        "queryLocator": queryLocator
    }
    response = requests.post(url_2, headers=headers, data=data)
    crm = response.json()
    data = pd.DataFrame(crm["data"]["records"])
    K_visit_df_attendant = pd.concat([K_visit_df_attendant, data], ignore_index=True, sort=False)
    
    if not crm['queryLocator']:
        break
    queryLocator = crm['queryLocator']
    
K_visit_df = pd.concat([K_visit_df, K_visit_df_attendant])

# %%
# Tasks_df5 = pd.concat([Tasks_df2,Tasks_df3, Tasks_df4])
Tasks_df5 = pd.concat([Tasks_df2, Tasks_df3])

Tasks_df5 = Tasks_df5.drop('id_y', axis=1)
Tasks_df5 = Tasks_df5.reset_index(drop=True)
Tasks_df5.columns
Tasks_df5 = Tasks_df5.drop('dimDepart_y', axis=1)
Tasks_df5 = pd.merge(Tasks_df5, user_df, left_on = '區域', right_on = 'name', how = 'left')
Tasks_df5 = Tasks_df5.rename(columns={'dimDepart_x':'dimDepart', 'id_y':'ownerId', 'id_x':'id'})

Tasks_df5
# Out:
# Empty DataFrame
# Columns: [id, name_x, customItem3__c, customItem8__c, 邀約日期, customItem58__c, customItem50__c, customItem42__c, entityType, dimDepart, 區域, approvalStatus, customItem11__c, customItem10__c, name_y, customItem1__c, ownerId, name_y, dimDepart_y]
# Index: []

# %%
# 去重 保留第一筆
Tasks_df6 = Tasks_df5.drop_duplicates(subset='customItem42__c', keep='last')

# 重複的資料
duplicates_df = Tasks_df5[Tasks_df5.duplicated(subset='customItem42__c', keep='last')]

duplicates_df
# Out:
# Empty DataFrame
# Columns: [id, name_x, customItem3__c, customItem8__c, 邀約日期, customItem58__c, customItem50__c, customItem42__c, entityType, dimDepart, 區域, approvalStatus, customItem11__c, customItem10__c, name_y, customItem1__c, ownerId, name_y, dimDepart_y]
# Index: []

# %%
K_invite_task = Tasks_df6

# 去除已K大+已邀約
K_invite_task = K_invite_task[~K_invite_task['customItem42__c'].isin(K_visit_df['联系人'].drop_duplicates())]

K_invite_task = K_invite_task[['customItem42__c',
                               'entityType',
                               'customItem1__c',
                               'customItem3__c',
                               'customItem58__c',
                               'customItem10__c',
                               'dimDepart',
                               'customItem11__c',
                               'ownerId',
                               'customItem50__c']]
K_invite_task = K_invite_task.astype(str)
K_invite_task = K_invite_task[K_invite_task['customItem10__c']!='']
K_invite_task['customItem10__c'].value_counts()
K_invite_task['customItem58__c'] = K_invite_task['customItem58__c'].replace('nan', '')
K_invite_task
# Out:
#        customItem42__c        entityType customItem1__c customItem3__c  \
# 0     2836147222959565  3074631761565155     2025-03-14      已邀K大但时间未定
# 1     2836129559467525  3074631761565155     2025-03-14      已邀K大但时间未定
# 2     2836120684074512  3074631761565155     2025-03-14      已邀K大但时间未定
# 3     2836125545174541  3074631761565155     2025-03-14      已邀K大但时间未定
# 4     2836097105597969  3074631761565155     2025-03-14      已邀K大但时间未定
# ...                ...               ...            ...            ...
# 1164  2836151117010443  3074631761565155     2025-03-14       K大-客户未上线
# 1165  2836125619787219  3074631761565155     2025-03-14       K大-客户未上线
# 1166  2836129585600028  3074631761565155     2025-03-14       K大-客户未上线
# 1167  2836111834584544  3074631761565155     2025-03-14       K大-客户未上线
# 1168  2836117301712341  3074631761565155     2025-03-14       K大-客户未上线
#
#      customItem58__c   customItem10__c         dimDepart   customItem11__c  \
# 0                     3321172257968944  2794748093863381  2756263923373550
# 1                     3715951347749679  2794755576436161  2668687488258842
# 2                     2709514453554019  2794759388501504  2756224402462161
# 3                     3715951347749679  2794748093863381  2756225200100832
# 4                     3708943322109405  2794757854221788  2756264199034399
# ...              ...               ...               ...               ...
# 1164                  3061996561339856  2794743622637096  2756264055887371
# 1165                  3309799618417431  2794758458791434  2756264320505377
# 1166                  3111521648169795  2794516231657004  2756233296057834
# 1167                  3063328310809429  2794755360101904  2678363516752640
# 1168                  3111521648169795  2794748692452887  2756225339217451
#
#                ownerId customItem50__c
# 0     2957376513676107
# 1     2957358145311573
# 2     2886699443049988
# 3     2957376513676107
# 4     2955760491206184
# ...                ...             ...
# 1164  2957479963366891
# 1165  2957372554761024
# 1166  2957472544494445
# 1167  2957360699085671
# 1168  2957376973067115
#
# [1166 rows x 10 columns]

# %%
'''
ask bulk id
'''
url_2 = "https://api-scrm.xiaoshouyi.com/rest/bulk/v2/job"
headers = {
    "Authorization": f"Bearer {ac_token}",
    "Content-Type":"application/json"
}
data = {
     "data": {
        "operation": "insert",####################################################################3
        "object": "customEntity14__c",
        "execOption": ["CHECK_RULE", "CHECK_DUPLICATE"]
    }
    
}
response = requests.post(url_2, headers = headers, json = data)
test = response.json()
bulk_id = test["result"]["id"]
print(bulk_id)
# Out:
# e9fa96a8caa871e0ab36de8779d0f0cf46c1595a06854c46b9dce44742688f2e

# %%
'''
insert to crm if dataframe over 5000
'''
batch_size = 5000


num_batches = (len(K_invite_task) + batch_size - 1) // batch_size

all_responses = []

current_batch_index = 0

while current_batch_index < num_batches:
    start_index = current_batch_index * batch_size
    end_index = (current_batch_index + 1) * batch_size
    current_batch_df = K_invite_task.iloc[start_index:end_index]
    json_data = current_batch_df.to_dict(orient='records')
    
    url_2 = "https://api-scrm.xiaoshouyi.com/rest/bulk/v2/batch"
    headers = {
        "Authorization": f"Bearer {ac_token}",
        "Content-Type":"application/json"
    }
    data = {
        "data": {
            "jobId": f"{bulk_id}",
            "datas": json_data
        }
    }
    response = requests.post(url_2, headers=headers, json=data)
    all_responses.append(response)
    current_batch_index += 1
for response in all_responses:
    pass

# %%
'''
select from Tasks 
'''
url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/query/xoqlScroll"

headers = {
    "Authorization": f"Bearer {ac_token}",
    "Content-Type":"application/x-www-form-urlencoded"
}

queryLocator = ''

Tasks_df = pd.DataFrame()

while True:
    data = {
        "xoql": '''
        SELECT 
        id,
        name, 
        customItem10__c, 
        customItem3__c, 
        approvalStatus
        FROM customEntity14__c 
        WHERE 
            entityType = '3074631761565155'
        AND
            createdBy = '3052177351988706'
        ''',
        "batchCount": 2000,
        "queryLocator": queryLocator
    }
    response = requests.post(url_2, headers=headers, data=data)
    crm = response.json()
    data = pd.DataFrame(crm["data"]["records"])
    Tasks_df = pd.concat([Tasks_df, data], ignore_index=True, sort=False)
    
    if not crm['queryLocator']:
        break
    queryLocator = crm['queryLocator']
    
Tasks_df['approvalStatus']= Tasks_df['approvalStatus'].astype(str)
Tasks_df = Tasks_df.loc[Tasks_df['approvalStatus'].str.contains("待提交")] 

Tasks_df
# Out:
#                       id         name   customItem10__c customItem3__c  \
# 139434  3721551160169216  CTM01391862  3061996561339856       K大-客户未上线
# 139435  3721551160169217  CTM01391863  3177059397064225       K大-客户未上线
# 139438  3721551160169220  CTM01391866  3238857117242178       K大-客户未上线
# 139439  3721551160169221  CTM01391867  3177059397064225       K大-客户未上线
# 139457  3721551160169239  CTM01391955  3063328310809429       K大-客户未上线
# 139723  3721551161431528  CTM01392094  3238857117242178       K大-客户未上线
# 139785  3721551161840387  CTM01391431  3061996561339856       K大-客户未上线
# 139949  3721551163102674  CTM01392110  3063328310809429       K大-客户未上线
# 139951  3721551163102676  CTM01392112  3133285968467485       K大-客户未上线
# 140247  3721551222461917  CTM01392337  3038358776664921       K大-客户未上线
# 140248  3721551222461918  CTM01392338  3063328310809429       K大-客户未上线
# 140249  3721551222461919  CTM01392339  3061996561339856       K大-客户未上线
#
#        approvalStatus
# 139434        ['待提交']
# 139435        ['待提交']
# 139438        ['待提交']
# 139439        ['待提交']
# 139457        ['待提交']
# 139723        ['待提交']
# 139785        ['待提交']
# 139949        ['待提交']
# 139951        ['待提交']
# 140247        ['待提交']
# 140248        ['待提交']
# 140249        ['待提交']

# %%
'''
submit_task
'''

status_url = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/creekflow/task/actions/preProcessor"
task_url = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/creekflow/task"
headers = {
        "Authorization": f"Bearer {ac_token}",
        "Content-Type": "application/json"
    }

def preProcessor(process_ID):
    status_body = {
        "data": {
            "action": "submit",
            "entityApiKey": "customEntity14__c",
            "dataId": process_ID }}

    response = requests.post(status_url, headers=headers, json=status_body)
    crm_json = response.json()['data']
    return crm_json

tasks_df_last_row = Tasks_df.iloc[-1]
approval_status = preProcessor(tasks_df_last_row['id'])

def submit_task(row):
    data_id = row['id']
    task_id = row['customItem10__c']
    url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/creekflow/task"
    headers = {
        "Authorization": f"Bearer {ac_token}",
        "Content-Type": "application/json"
    }

    data = {
        "data": {
            "action": "submit",
            "entityApiKey": "customEntity14__c",
            "dataId": data_id,
            "procdefId": approval_status['procdefId'],
            "nextTaskDefKey": approval_status['nextTaskDefKey'],
            "nextAssignees": [task_id],
            "ccs": [task_id]  
        }
    }

    response = requests.post(url_2, headers=headers, json=data)
    result = response.json()
    print(f"Response for dataId {data_id}: {result}")

# Assuming data_ids is your DataFrame
data_ids_df = Tasks_df[['id', 'customItem10__c']]

# Create a thread for each row in the DataFrame
threads = []
for index, row in data_ids_df.iterrows():
    thread = threading.Thread(target=submit_task, args=(row,))
    threads.append(thread)
    thread.start()
    time.sleep(0.08)

# Wait for all threads to finish
for thread in threads:
    thread.join()
# Out:
# Response for dataId 3721551160169216: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721551160169217: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721551160169220: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721551160169221: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721551160169239: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721551161431528: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721551163102674: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721551163102676: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721551222461917: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721551161840387: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721551222461918: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721551222461919: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}

# %%
'''
get procInstId
'''
Tasks_df2 = Tasks_df6[['id']]
# Tasks_df2 = Tasks_df4[['id']]
base_url = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/creekflow/history/filter?entityApiKey=customEntity14__c&dataId="

def fetch_data(data_id):
    print(data_id)
    api_url = f"{base_url}{data_id}&stageFlg=false"
    response = requests.get(api_url, headers=headers)
    if response.status_code == 200:
        api_data = response.json()
        if api_data["data"]:
          print(api_data["data"][-1]["procInstId"])
          return json.dumps({ "dataId": data_id, "procInstId": api_data["data"][-1]["procInstId"] })
          # df = pd.DataFrame(api_data["data"][0]["procInstId"], dtype=str)
        else:
            print("Data is empty")
            return
    else:
        print(f"Error accessing API for dataId {data_id}. Status code: {response.status_code}")

        return
    

# Set the maximum number of threads you want to use
max_threads = 2  # You can adjust this based on your needs


with ThreadPoolExecutor(max_threads) as executor:
    # Use executor.map to asynchronously fetch data for each row in parallel
    dfs = list(executor.map(fetch_data, Tasks_df2['id']))
    # Add a time delay between each thread

json_data = [entry for entry in dfs if entry is not None]
Tasks_df2 = pd.json_normalize([json.loads(entry) for entry in json_data])
# Out:
# 3710375617336806
# 3710443012526892
# 3710465175638795
# 3710448305279785
# 3710376605913895
# 3710566963401482
# 37104651178367763710568093881097
#
# 3710606369821446
# 3710643478468051
# 3710656564450810
# 3710644978144017
# 3710612425184764
# 3710654027879189
# 3710656564450789
# 3710664710853392
# 3710656568562449
# 3710738520609541
# 3710745022223840
# 3710743758017287
# 3710671437484827
# 3710774559610334
# 3710789621846790
# 3710790159472091
# 3710745025450757
# 3710794927641378
# 3710803834721080
# 3710812944290590
# 3710803396662772
# 3720145648276953
# 37108189448329713720297192347111
#
# 3720145648276954
# 3720145648276955
# 3720147155260186
# 3720145648276956
# 3720147155260208
# 3720145648276957
# 3720147156489691
# 3720145648276958
# 3720297193182677
# 3720145648276959
# 3720147156489715
# 3720145648276960
# 3720147160060701
# 3720145648276961
# 3720297192347087
# 3720147174445857
# 3720145648276962
# 3720145648276963
# 3720147169121760
# 3720145648276964
# 3720147169121738
# 3720145648276965
# 3720297188856635
# 3720145648276966
# 3720147174445835
# 3720145648276967
# 3720147175740172
# 3720145648276968
# 3720297185022776
# 3720145648276969
# 3720147175740194
# 3720145648276970
# 3720147182736850
# 3720145648276971
# 3720147175740216
# 3720145648276972
# 3720147182736835
# 3720146604528431
# 3720148879790894
# 3720146604528433
# 3720148883068399
# 3720146607052224
# 3720148889555718
# 3720146607052226
# 3720148891751878
# 3720146607052227
# 3720148891751900
# 3720146607052228
# 3720148891751922
# 3720146607052229
# 3720148896420617
# 3720146607052230
# 3720148896420639
# 3720146607052231
# 3720148889555743
# 3720146607052232
# 3720148889555766
# 3720146607052233
# 3720148896420664
# 3720146607052234
# 3720148905448909
# 3720146607052235
# 3720148906841551
# 3720146607052236
# 3720148905448953
# 3720146607052237
# 3720148905448931
# 3720146607052238
# 3720148910461712
# 3720146607052239
# 3720148906841574
# 3720146607052240
# 3720148906841598
# 3720146607052241
# 3720148910461735
# 3720146607052242
# 3720148910461758
# 3720146607052243
# 3720148916589333
# 3720146607052244
# 3720148918834645
# 3720146607052245
# 3720148916589356
# 3720146607052252
# 3720148924650241
# 3720146607052253
# 3720148918834667
# 3720146607052254
# 3720148925912515
# 3720146607052255
# 3720148924650263
# 3720146607052256
# 3720148925912538
# 3720146607052257
# 3720148924650286
# 3720146607052258
# 3720148925912560
# 3720146607052259
# 3720148924650303
# 3720146607052260
# 3720148929598230
# 3720146607052261
# 3720148929598260
# 3720148929598215

# %%
'''
withdraw_task
'''

def withdraw_task(row):
    data_id = row['dataId']
    task_id = row['procInstId']
    url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/creekflow/task"
    headers = {
        "Authorization": f"Bearer {ac_token}",
        "Content-Type": "application/json"
    }
    data = {
        "data": {
            "action": "withdraw",
            "entityApiKey": "customEntity14__c",
            "dataId": data_id,
            "procInstId": task_id
        }
    }

    response = requests.post(url_2, headers=headers, json=data)
    result = response.json()
    print(f"Response for dataId {data_id}: {result}")

# Assuming data_ids is your DataFrame
data_ids_df = Tasks_df2[['dataId', 'procInstId']]

# Create a thread for each row in the DataFrame
threads = []
for index, row in data_ids_df.iterrows():
    thread = threading.Thread(target=withdraw_task, args=(row,))
    threads.append(thread)
    thread.start()
    time.sleep(0.08)

# Wait for all threads to finish
for thread in threads:
    thread.join()
# Out:
# Response for dataId 3710375617336806: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3710443012526892: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3710448305279785: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3710566963401482: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3710606369821446: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3710643478468051: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3710644978144017: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3710654027879189: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3710664710853392: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3710738520609541: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3710774559610334: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3710743758017287: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3710790159472091: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3710794927641378: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3710812944290590: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276953: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276954: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276955: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276956: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276957: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276958: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276960: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276959: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276961: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276962: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276963: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276964: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276965: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276966: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276967: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276968: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276969: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276970: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276971: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276972: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276973: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276974: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276975: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276976: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145648276977: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646090: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646091: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646092: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646093: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646094: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646095: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646096: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646098: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646097: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646099: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646100: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646101: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646102: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646103: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646104: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646105: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646107: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646106: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646108: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646109: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646111: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646112: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646113: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646114: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646115: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646110: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646116: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646117: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646118: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646119: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646120: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646123: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646121: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646122: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646124: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646125: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646126: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646127: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646129: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720145717646128: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146542253505: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350097: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146542253504: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350099: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350098: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350100: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350101: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350103: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350104: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350102: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350105: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350106: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350107: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350108: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350109: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350110: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350111: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350112: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350113: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350114: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350116: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350115: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350117: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350118: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350119: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350120: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350121: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350122: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350123: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350124: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350125: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545350126: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146546397952: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146546
{'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906461: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906462: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906463: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906464: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906465: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906466: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906467: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906468: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906469: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906470: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906471: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906472: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906473: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906474: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906475: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906476: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906477: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906478: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906479: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906480: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146545906481: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# ...
# Response for dataId 3720146587424233: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146587424234: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146587424235: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146587424236: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146587424237: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146587424238: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146587424239: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146587424241: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146587424240: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156736: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156737: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156738: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156739: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156740: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156741: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156742: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156743: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156744: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156745: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156746: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156747: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156748: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156749: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156750: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156751: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156752: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156753: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156760: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156761: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156762: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156763: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156764: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156765: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156766: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156767: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156768: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156769: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156770: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156772: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156773: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156774: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156775: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156776: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156777: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156778: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156779: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156780: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156781: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156782: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156783: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156784: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146595156785: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146596763072: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146596763073: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146596763074: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146596763075: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146596763076: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146596763083: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146596763084: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146596763085: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220693: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220692: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220694: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220695: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220696: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220697: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220698: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220699: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220700: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220701: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220703: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220702: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220705: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220704: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220706: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220707: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220708: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220709: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220710: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220711: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220712: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220713: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220714: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220716: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}Response for dataId 3720146599220715: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
#
# Response for dataId 3720146599220718: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220717: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220719: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220720: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146599220721: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528388: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528390: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528389: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528391: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528392: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528393: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528394: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528395: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528396: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528397: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528399: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528400: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528398: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528401: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528402: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528403: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528404: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528405: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528406: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528407: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528408: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528409: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528410: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528411: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528413: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528414: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528412: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528415: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528416: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528417: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528424: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528425: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528426: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528428: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}Response for dataId 3720146604528427: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
#
# Response for dataId 3720146604528429: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528430: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528431: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146604528433: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052224: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052226: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052227: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052228: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052229: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052230: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052231: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052232: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052234: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052233: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052235: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052236: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052238: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052237: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052240: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052239: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052241: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052242: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052243: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052245: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052252: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052244: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052253: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052254: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052255: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052256: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052258: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052260: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052261: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052259: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3720146607052257: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}

# %%
'''
ask bulk id
'''
url_2 = "https://api-scrm.xiaoshouyi.com/rest/bulk/v2/job"
headers = {
    "Authorization": f"Bearer {ac_token}",
    "Content-Type":"application/json"
}
data = {
     "data": {
        "operation": "delete",####################################################################3
        "object": "customEntity14__c",
        "execOption": ["CHECK_RULE", "CHECK_DUPLICATE"]
    }
    
}
response = requests.post(url_2, headers = headers, json = data)
test = response.json()
bulk_id = test["result"]["id"]
print(bulk_id)

Tasks_df3 = Tasks_df2[['dataId']]
Tasks_df3 = Tasks_df3.rename(columns={'dataId':'id'})
# Out:
# e9fa96a8caa871e0ab36de8779d0f0cf0e2e32bae52944f28a27ffbf7e9c2d4a

# %%
'''
delete to crm if dataframe over 5000
'''
batch_size = 5000


num_batches = (len(Tasks_df3) + batch_size - 1) // batch_size

all_responses = []

current_batch_index = 0

while current_batch_index < num_batches:
    start_index = current_batch_index * batch_size
    end_index = (current_batch_index + 1) * batch_size
    current_batch_df = Tasks_df3.iloc[start_index:end_index]
    json_data = current_batch_df.to_dict(orient='records')
    
    url_2 = "https://api-scrm.xiaoshouyi.com/rest/bulk/v2/batch"
    headers = {
        "Authorization": f"Bearer {ac_token}",
        "Content-Type":"application/json"
    }
    data = {
        "data": {
            "jobId": f"{bulk_id}",
            "datas": json_data
        }
    }
    response = requests.post(url_2, headers=headers, json=data)
    all_responses.append(response)
    current_batch_index += 1
for response in all_responses:
    pass
