# %%
import pandas as pd
import json
import requests
import time
import threading
from datetime import datetime, timedelta
from concurrent.futures import ThreadPoolExecutor
from sqlalchemy import create_engine

# %%
# 取得 Token , 設置請求參數 (大陸)
url = "https://login.xiaoshouyi.com/auc/oauth2/token"
headers = {
    "Content-Type": "application/x-www-form-urlencoded"
}
data = {
    "grant_type": "password",
    "client_id": "473f31e3a6cb9cafaec3ddf36d20092b",
    "client_secret": "ddfed65f5aeebacd0f54eaa464fcb043",
    "redirect_uri": "https://api-scrm.xiaoshouyi.com/",
    "username": "11021041@twkd.com",
    "password": "Marcellin01oiH88cCI"
}

# 發送 post 請求
response = requests.post(url, headers=headers, data=data)

if response.status_code == 200:
    print(response.json())
else:
    print("請求失敗, 狀態碼:", response.status_code)

content = response.json()
ac_token = content["access_token"]


print(ac_token)
# Out:
# {'access_token': 'b470b0021985af2222eb5c9c4f5508226f6b57ef6318c21f5e55ec544a1f310d.MjM2OTI2Njk5ODU2MzExMw==0', 'token_type': 'Bearer', 'expires_in': 86399, 'scope': 'all prm crm', 'tenant_id': '2369266998563113', 'login_type': '', 'encryption_key': '', 'client_id': '473f31e3a6cb9cafaec3ddf36d20092b', 'passport_id': '3052172005298442', 'mobile_params': '', 'instance_uri': 'api-scrm.xiaoshouyi.com'}
# b470b0021985af2222eb5c9c4f5508226f6b57ef6318c21f5e55ec544a1f310d.MjM2OTI2Njk5ODU2MzExMw==0

# %%
'''
select from user 人員名單
'''
url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/query/xoqlScroll"
headers = {
    "Authorization": f"Bearer {ac_token}",
    "Content-Type":"application/x-www-form-urlencoded"
} 
data = {
    "xoql": "select id, name, dimDepart from user",
    #"xoql": "insert into contact(contactName, phone, email) values('貴夫人', '0912345678', 'kkdd@gmail.com')"
    "batchCount": 2000
}
response2 = requests.post(url_2, headers=headers, data = data)
ownerId = response2.json()
print(ownerId)
user_df = pd.json_normalize(ownerId["data"]["records"])    

# user_df[user_df['id']=='']
# user_df[user_df['name']=='']
# Out:
# {'code': '200', 'msg': '', 'errorInfo': None, 'debugInfo': None, 'data': {'totalSize': 629, 'count': 629, 'records': [{'id': '2369301140133416', 'name': 'CRM管理员', 'dimDepart': '2586653553808230'}, {'id': '2508839248500196', 'name': '谢敏', 'dimDepart': '2369301140133408'}, {'id': '2508849255192015', 'name': '唐雪梅', 'dimDepart': '2746547845976859'}, {'id': '2531364166931931', 'name': '俞丽', 'dimDepart': '2369301140133408'}, {'id': '2531364279604701', 'name': '宋冀泽', 'dimDepart': '2369301140133408'}, {'id': '2586658357285641', 'name': '徐玮珍', 'dimDepart': '2586637755765606'}, {'id': '2586659192656747', 'name': '杨卫卫', 'dimDepart': '2586653553808212'}, {'id': '2586660964537152', 'name': '金海洋', 'dimDepart': '2586653553808230'}, {'id': '2586661145334617', 'name': '教育训练', 'dimDepart': '2746546870686577'}, {'id': '2586661881402202', 'name': '蔡家维', 'dimDepart': '2369301140133408'}, {'id': '2586663184339728', 'name': '刘俐君', 'dimDepart': '2586649840522022'}, {'id': '2586670417466176', 'name': '马梦文', 'dimDepart': '3418961396667154'}, {'id': '2586670520013616', 'name': '黄燕龙', 'dimDepart': '2586639777157974'}, {'id': '2586671634436951', 'name': '邱健贸', 'dimDepart': '2586650503320362'}, {'id': '2586672257831771', 'name': '文琴', 'dimDepart': '3418962860414439'}, {'id': '2589286500127564', 'name': '赵宁', 'dimDepart': '2586637755765606'}, {'id': '2644467339219785', 'name': '陈晶晶', 'dimDepart': '3058032515700206'}, {'id': '2644467541857102', 'name': '陈胜楠', 'dimDepart': '2794747741885967'}, {'id': '2644467541857126', 'name': '胡聪', 'dimDepart': '2794757854221788'}, {'id': '2644467557176089', 'name': '赵彦慧', 'dimDepart': '2586639777157974'}, {'id': '2644467588813632', 'name': '楼俊', 'dimDepart': '3058032515700206'}, {'id': '2644467588813655', 'name': '李静静', 'dimDepart': '3058032515700206'}, {'id': '2644467588813676', 'name': '马梦伟', 'dimDepart': '2794757562668484'}, {'id': '2644467600282481', 'name': '冯丽丽', 'dimDepart': '2794749524432335'}, {'id': '2644467632919319', 'name': '孙萍萍', 'dimDepart': '2586639777157974'}, {'id': '2644467655644008', 'name': '袁贤', 'dimDepart': '2794755975468573'}, {'id': '2644467656643401', 'name': '徐祎', 'dimDepart': '2794757704390185'}, {'id': '2644467684299554', 'name': '李荣荣', 'dimDepart': '2794757562668484'}, {'id': '2644467684758275', 'name': '孟雨', 'dimDepart': '2794755576436181'}, {'id': '2644467712709471', 'name': '汪冰玉', 'dimDepart': '2794745160947247'}, {'id': '2644467713643329', 'name': '彭扬凤', 'dimDepart': '3418961396667154'}, {'id': '2644467713643373', 'name': '于小美', 'dimDepart': '2586649840522010'}, {'id': '2644467740365592', 'name': '张梦丽', 'dimDepart': '2586639777157974'}, {'id': '2644467753603878', 'name': '张艳', 'dimDepart': '3418962860414439'}, {'id': '2644467778261847', 'name': '赵雅恬', 'dimDepart': '2644436119278385'}, {'id': '2644467782030179', 'name': '周丽', 'dimDepart': '3124737640650190'}, {'id': '2644467810095889', 'name': '淡幼可', 'dimDepart': '2586639777157974'}, {'id': '2644467810538268', 'name': '王美欢', 'dimDepart': '2794747004802525'}, {'id': '2644467841880929', 'name': '李莹', 'dimDepart': '2586639777157974'}, {'id': '2644467844961088', 'name': '韦建华', 'dimDepart': '2794748093863381'}, {'id': '2644467844961133', 'name': '吕情怡', 'dimDepart': '2794516231657004'}, {'id': '2644467870077723', 'name': '王建瑾', 'dimDepart': '2794749626996235'}, {'id': '2644467882972008', 'name': '韦晓琦', 'dimDepart': '2794746540529182'}, {'id': '2644467904697174', 'name': '翁妙宝', 'dimDepart': '2586639777157974'}, {'id': '2644467912463138', 'name': '赵琴', 'dimDepart': '2794746540529182'}, {'id': '2644467940135695', 'name': '曹圣英', 'dimDepart': '2794747004802525'}, {'id': '2644467940135719', 'name': '陈瑾', 'dimDepart': '2794746540529182'}, {'id': '2644467970249477', 'name': '林丽君', 'dimDepart': '2794743622637096'}, {'id': '2644467970249500', 'name': '谢珊珊', 'dimDepart': '2794516231657004'}, {'id': '2644467998561049', 'name': '汪珊珊', 'dimDepart': '3058032515700206'}, {'id': '2644468001887040', 'name': '王达KD', 'dimDepart': '3418962860414439'}, {'id': '2644468 ...

# %%
'''
select related_contact 客戶關係聯絡人
'''

url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/query/xoqlScroll"
headers = {
    "Authorization": f"Bearer {ac_token}",
    "Content-Type":"application/x-www-form-urlencoded"
    # Replace with your actual access token
}
queryLocator = ''
contact_related = pd.DataFrame()
 
while True:
    data = {
        "xoql": '''
        SELECT 
        contactCode__c 联系人代号, 
        id 客户联系人关系, 
        customItem25__c 关系状态,
        dimDepart, 
        customItem38__c 联系人代号_舊,
        customItem119__c 有效_总,
        account__c.customItem335__c 经销商签约系列
        FROM accContactRelation__c 
        ''',
        "batchCount": 2000,
        "queryLocator": queryLocator
    }
    response = requests.post(url_2, headers=headers, data=data)
    crm = response.json()
    data = pd.DataFrame(crm["data"]["records"])
    contact_related = pd.concat([contact_related, data], ignore_index=True, sort=False)
    
    if not crm['queryLocator']:
        break
    queryLocator = crm['queryLocator']

# 有效(总) 為 有效
contact_related['有效_总']= contact_related['有效_总'].astype(str)
contact_related = contact_related[~contact_related['有效_总'].str.contains("无效")]

contact_related['经销商签约系列'] = contact_related['经销商签约系列'].astype(str)

contact_related = contact_related[~contact_related['经销商签约系列'].str.contains("全系列", na=False)]

# %%
# from datetime import datetime

# # Unix 时间戳（以毫秒为单位）
# timestamp_ms = 1706630400000

# # 将毫秒转换为秒
# timestamp_s = timestamp_ms / 1000

# # 使用 datetime.fromtimestamp() 方法将 Unix 时间戳转换为日期
# date = datetime.fromtimestamp(timestamp_s)

# print(date)

# %%
# from datetime import datetime

# # 输入日期
# date_string = "2023-03-02"
# date_format = "%Y-%m-%d"

# # 将日期字符串解析为 datetime 对象
# date = datetime.strptime(date_string, date_format)

# # 将 datetime 对象转换为 Unix 时间戳（以毫秒为单位）
# timestamp_ms = int(date.timestamp() * 1000)

# print(timestamp_ms)

# %%
'''
select from trackingrecord 追蹤紀錄
'''
url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/query/xoqlScroll"
headers = {
    "Authorization": f"Bearer {ac_token}",
    "Content-Type":"application/x-www-form-urlencoded"
}

date_to_convert = datetime(2024, 1, 1) 
# date_to_convert = datetime(2023, 3, 2) # 大陸銷售易上線日期
timestamp = int(date_to_convert.timestamp() * 1000)

queryLocator = ''
tracking = pd.DataFrame()
while True:
    data = {
        "xoql": f'''
        SELECT
        name 业务工作记录代号,
        customItem55__c.contactCode__c 联系人代号,
        customItem55__c.customItem38__c 联系人代号_旧,
        customItem45__c 最近工作内容,
        customItem132__c 无效电访类型,
        customItem106__c 电访接通无效,
        customItem115__c 是否邀约K大,
        customItem40__c 最近联系时间,
        customItem4__c 触客类型,
        customItem55__c 客户联系人关系, 
        dimDepart.departName 资料区域名称,
        customItem59__c 联系人,
        customItem27__c customItem70__c,
        accountCode__c 公司代号
        FROM customEntity15__c
        WHERE customItem40__c >= {timestamp}
        ''',
        "batchCount": 2000,
        "queryLocator": queryLocator
        
    }
    
    response2 = requests.post(url_2, headers=headers, data = data)
    exist = response2.json()
    data = pd.DataFrame(exist["data"]["records"])
    tracking = pd.concat([tracking, data], ignore_index=True, sort=False)
    
    if not exist['queryLocator']:
        break
    queryLocator = exist['queryLocator']
    
tracking['最近联系时间'] = tracking['最近联系时间'].astype(float)
tracking['最近联系时间'] = tracking['最近联系时间'].apply(lambda x: pd.to_datetime(x / 1000.0, unit='s', utc=True))
tracking['最近联系时间'] = tracking['最近联系时间'].dt.tz_convert('Asia/Taipei')
tracking['最近联系时间'] = tracking['最近联系时间'].dt.strftime('%Y-%m-%d')
tracking = tracking.sort_values(by='最近联系时间', ascending=True) 

current_datetime = datetime.now()
target_date = current_datetime - timedelta(days=90) 

tracking['无效电访类型']= tracking['无效电访类型'].astype(str)
tracking['电访接通无效']= tracking['电访接通无效'].astype(str)
tracking['最近联系时间'] = pd.to_datetime(tracking['最近联系时间'])

# 三个月内联系过
tracking_month = tracking[tracking['最近联系时间'] >= target_date] 

# 联络人退休/转行/公司 & 电话暂停/空号/号码错误
tracking_invalid = tracking[(tracking['无效电访类型'].str.contains("联络人|电话"))]

# 号码无效
tracking_invalid_2 = tracking[(tracking['电访接通无效'].str.contains("号码无效|智齒"))]

# 提取 tracking_invalid 中的聯絡人代號
existing_contact_codes = tracking_invalid['联系人代号']

# 检查 tracking_invalid_2 中的聯絡人代號是否存在于 tracking_invalid 中
mask = ~tracking_invalid_2['联系人代号'].isin(existing_contact_codes)

# 过滤出符合条件的行
tracking_invalid_2 = tracking_invalid_2[mask]

# 智齒攔截名單
tracking_zhichi = tracking[(tracking['电访接通无效'].str.contains("智齒"))]

K_invite_rejected = pd.concat([tracking_month, tracking_invalid, tracking_invalid_2])

# %%
經營開發 = pd.read_excel("經營開發_all_20250310.xlsx", dtype='object')
經營開發 = pd.merge(經營開發, tracking, on = '联系人代号', how = 'left')
經營開發 = 經營開發.sort_values(by='最近联系时间', na_position='first')
經營開發 = 經營開發[~經營開發['联系人代号'].isin(K_invite_rejected['联系人代号'].drop_duplicates())]
經營開發 = 經營開發.drop_duplicates(subset=['联系人代号'], keep='last')

# %%
# url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/xobjects/customEntity14__c/busiType"
# headers = {
#     "Authorization": f"Bearer {ac_token}"
# }
# response2 = requests.get(url_2, headers = headers)
# Task_desc = response2.json()

# Task_desc

# %%
'''
from 銷售易 其他電拜訪(原:電/拜訪)

# 已给出的交办，但没有及时处理
1、交办管理中【业务类型】：业务每月交办（业管指定）、行销指定产品顾问邀约K大交办、发放回访交办
2、交办管理中【审批状态】：审批中

# 短信群发回复有意向客户名单
1、交办管理中【业务类型】：行销指定产品顾问邀约K大交办
2. 交办管理中【工作主旨】：短信回复需要样册

'''

url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/query/xoqlScroll"
headers = {
    "Authorization": f"Bearer {ac_token}",
    "Content-Type":"application/x-www-form-urlencoded"
}
queryLocator = ''
Tasks_df = pd.DataFrame()

while True:
    data = {
        "xoql": f'''
        SELECT 
        name, 
        customItem42__c.contactCode__c 联系人代号, 
        createdAt 创建日期,
        customItem3__c 工作主旨, 
        customItem8__c 执行状态,
        approvalStatus 审批状态
        FROM 
            customEntity14__c
        WHERE 
            (entityType = '2825954839057885' OR entityType = '2954421329187625' OR entityType = '3220592941503278')
        ''',
        "batchCount": 2000,
        "queryLocator": queryLocator
    }
    response = requests.post(url_2, headers=headers, data=data)
    crm = response.json()
    data = pd.DataFrame(crm["data"]["records"])
    Tasks_df = pd.concat([Tasks_df, data], ignore_index=True, sort=False)
    
    if not crm['queryLocator']:
        break
    queryLocator = crm['queryLocator']

Tasks_df['创建日期'] = Tasks_df['创建日期'].astype(float)
Tasks_df['创建日期'] = Tasks_df['创建日期'].apply(lambda x: pd.to_datetime(x / 1000.0, unit='s', utc=True))
Tasks_df['创建日期'] = Tasks_df['创建日期'].dt.tz_convert('Asia/Taipei')
Tasks_df['创建日期'] = Tasks_df['创建日期'].dt.strftime('%Y-%m-%d')
Tasks_df['创建日期'] = pd.to_datetime(Tasks_df['创建日期'])
# Tasks_df['执行状态']= Tasks_df['执行状态'].astype(str)
# Tasks_df1 = Tasks_df.loc[Tasks_df['执行状态'].str.contains("任务完成|接受任务")]  

Tasks_df['审批状态']= Tasks_df['审批状态'].astype(str)
Tasks_df1 = Tasks_df.loc[Tasks_df['审批状态'].str.contains("待提交") | Tasks_df['审批状态'].str.contains("审批中")]  

Tasks_df = Tasks_df.loc[Tasks_df['工作主旨'].str.contains("短信")]

# %%
K_invite = pd.merge(經營開發, contact_related, on = '联系人代号', how = 'inner')
K_invite = K_invite.drop_duplicates(subset=['联系人代号'], keep='last')

K_invite = K_invite[~K_invite['联系人代号'].isin(Tasks_df['联系人代号'].drop_duplicates())]
K_invite = K_invite[~K_invite['联系人代号'].isin(Tasks_df1['联系人代号'].drop_duplicates())]
# K_invite = K_invite[~K_invite['联系人代号'].isin(Tasks_daily['联系人代号'].drop_duplicates())]
K_invite = K_invite.rename(columns={'联系人_x':'联系人'})

# %%
# url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/query/xoqlScroll"
# headers = {
#     "Authorization": f"Bearer {ac_token}",
#     "Content-Type":"application/x-www-form-urlencoded"
# }
# queryLocator = ''
# Tasks_daily = pd.DataFrame()

# while True:
#     data = {
#         "xoql": f'''
#         SELECT 
#         name, 
#         customItem42__c.contactCode__c 联系人代号, 
#         createdAt 创建日期,
#         customItem3__c 工作主旨, 
#         customItem8__c 执行状态,
#         approvalStatus 审批状态
#         FROM 
#             customEntity14__c
#         WHERE 
#             entityType = '3074631761565155'
#         ''',
#         "batchCount": 2000,
#         "queryLocator": queryLocator
#     }
#     response = requests.post(url_2, headers=headers, data=data)
#     crm = response.json()
#     data = pd.DataFrame(crm["data"]["records"])
#     Tasks_daily = pd.concat([Tasks_daily, data], ignore_index=True, sort=False)
    
#     if not crm['queryLocator']:
#         break
#     queryLocator = crm['queryLocator']

# Tasks_daily['创建日期'] = Tasks_daily['创建日期'].astype(float)
# Tasks_daily['创建日期'] = Tasks_daily['创建日期'].apply(lambda x: pd.to_datetime(x / 1000.0, unit='s', utc=True))
# Tasks_daily['创建日期'] = Tasks_daily['创建日期'].dt.tz_convert('Asia/Taipei')
# Tasks_daily['创建日期'] = Tasks_daily['创建日期'].dt.strftime('%Y-%m-%d')
# Tasks_daily['创建日期'] = pd.to_datetime(Tasks_daily['创建日期']).dt.date

# current_date = current_datetime.date()

# Tasks_daily = Tasks_daily[Tasks_daily['创建日期'] >= current_date] 

# Tasks_daily

# %%
# 分公司信息 customEntity32__c
url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/query/xoqlScroll"
headers = {
    "Authorization": f"Bearer {ac_token}",
    "Content-Type":"application/x-www-form-urlencoded"
}
queryLocator = ''
sales_dimDepart = pd.DataFrame()

while True:
    data = {
        "xoql": '''
        SELECT 
        name 区域, 
        customItem47__c.name 电访人员
        FROM 
            customEntity32__c
        ''',
        "batchCount": 2000,
        "queryLocator": queryLocator
    }
    response = requests.post(url_2, headers=headers, data=data)
    crm = response.json()
    data = pd.DataFrame(crm["data"]["records"])
    sales_dimDepart = pd.concat([sales_dimDepart, data], ignore_index=True, sort=False)
    
    if not crm['queryLocator']:
        break
    queryLocator = crm['queryLocator']

sales_dimDepart = sales_dimDepart.drop_duplicates(subset=['区域', '电访人员'])
sales_dimDepart = sales_dimDepart[~(sales_dimDepart['区域'].str.contains('加盟商') | sales_dimDepart['区域'].str.contains('天猫') | sales_dimDepart['区域'].str.contains('经销商'))]
sales_dimDepart = sales_dimDepart[sales_dimDepart['电访人员'] != ""]

# %%
# 合併人員資訊表格
K_invite = K_invite.rename(columns={'资料区域名称_x':'资料区域名称','联系人_x':'联系人'})
K_invite = K_invite.drop(['customItem70__c'],axis=1)
K_invite = pd.merge(K_invite , sales_dimDepart ,left_on ='资料区域名称', right_on='区域', how='left')
K_invite = K_invite[~K_invite['资料区域名称'].str.contains("经销商|加盟商")]

# K_invite['電訪人員'].fillna('姚思瑋', inplace=True)

# 手機電話去重、加回
K_invite1 = K_invite[K_invite['联系人手机号'].apply(lambda x: isinstance(x, str) and len(x) == 11 and x != '00000000000')] 
K_invite1 = K_invite1.drop_duplicates(subset=['联系人手机号'], keep='last')

K_invite2 = K_invite[~(K_invite['联系人手机号'].isin(K_invite1['联系人手机号'].drop_duplicates(keep=False)))]
contact_related['关系状态']= contact_related['关系状态'].astype(str)
contact_resigned = contact_related[contact_related['关系状态'].str.contains('离职')]
K_invite2 = K_invite2[~(K_invite2['联系人代号'].isin(contact_resigned['联系人代号'].drop_duplicates(keep=False)))]

K_invite_all = pd.concat([K_invite1,K_invite2])

# %%
'''
from K大預約表 排除2024/5/26以來K過的(大陸美耐板上線)
'''

url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/query/xoqlScroll"
headers = {
    "Authorization": f"Bearer {ac_token}",
    "Content-Type":"application/x-www-form-urlencoded"
}
queryLocator = ''
K_visit_df = pd.DataFrame()
 
while True:
    data = {
        "xoql": '''
        SELECT 
        name,
        customItem29__c 联系人代号, 
        customItem6__c 客戶關係連絡人編號,
        customItem2__c 预约日期, 
        customItem40__c, 
        customItem9__c 联系人手机号
        FROM customEntity26__c
        ''',
        "batchCount": 2000,
        "queryLocator": queryLocator
    }
    response = requests.post(url_2, headers=headers, data=data)
    crm = response.json()
    data = pd.DataFrame(crm["data"]["records"])
    K_visit_df = pd.concat([K_visit_df, data], ignore_index=True, sort=False)
    
    if not crm['queryLocator']:
        break
    queryLocator = crm['queryLocator']

# # 從大陸銷售易上線那天起所有K大場次    
# K_visit_df['预约日期'] = pd.to_datetime(K_visit_df['预约日期'], unit='ms').dt.tz_localize('UTC').dt.tz_convert('Asia/Taipei')
# start_date = pd.Timestamp('2023-03-02', tz='UTC') # 大陸销售易上线日期
# K_visit_df['预约日期'] = pd.to_datetime(K_visit_df['预约日期'])
# K_visit_df = K_visit_df[K_visit_df['预约日期'] >= start_date]

# # 近三個月的K大場次
# K_visit_df['预约日期'] = pd.to_datetime(K_visit_df['预约日期'], unit='ms').dt.tz_localize('UTC').dt.tz_convert('Asia/Taipei')
# end_date = pd.Timestamp.now(tz='Asia/Taipei')
# start_date = end_date - pd.DateOffset(months=3)
# K_visit_df = K_visit_df[(K_visit_df['预约日期'] >= start_date) & (K_visit_df['预约日期'] < end_date)]

# 排除2024/5/26以來K過的
K_visit_df['预约日期'] = pd.to_datetime(K_visit_df['预约日期'], unit='ms').dt.tz_localize('UTC').dt.tz_convert('Asia/Taipei')
start_date = pd.Timestamp('2024-05-26', tz='UTC') # 大陸美耐板上線
K_visit_df['预约日期'] = pd.to_datetime(K_visit_df['预约日期'])
K_visit_df = K_visit_df[K_visit_df['预约日期'] >= start_date]

# 有舉行K大
K_visit_df['customItem40__c'] = K_visit_df['customItem40__c'].astype(str)
K_visit_df_held = K_visit_df[K_visit_df['customItem40__c'].str.contains("是")]

# 未來場次
today_date = datetime.now().strftime('%Y-%m-%d')
K_visit_df_future = K_visit_df[K_visit_df['预约日期'] >= today_date]

K_visit_df = pd.concat([K_visit_df_held, K_visit_df_future])


'''
from K大預約参會人
'''
url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/query/xoqlScroll"
headers = {
    "Authorization": f"Bearer {ac_token}",
    "Content-Type":"application/x-www-form-urlencoded"
}
queryLocator = ''
K_visit_df_attendant = pd.DataFrame()
 
while True:
    data = {
        "xoql": '''
        select 
        name,
        customItem1__c K大预约表编号,
        customItem6__c 联系人代号, 
        customItem5__c 联系人手机号
        from customEntity27__c
        ''',
        "batchCount": 2000,
        "queryLocator": queryLocator
    }
    response = requests.post(url_2, headers=headers, data=data)
    crm = response.json()
    data = pd.DataFrame(crm["data"]["records"])
    K_visit_df_attendant = pd.concat([K_visit_df_attendant, data], ignore_index=True, sort=False)
    
    if not crm['queryLocator']:
        break
    queryLocator = crm['queryLocator']
    
K_visit_df = pd.concat([K_visit_df, K_visit_df_attendant])

# # 排除K過3次及以上的人
# K_visit_df1 = K_visit_df.groupby('联系人手机号').size().reset_index(name='次數')
# K_visit_df1 = K_visit_df1[(K_visit_df1['联系人手机号'] != '') & (K_visit_df1['次數'] >= 3)]

# K_visit_df2 = K_visit_df.groupby('客戶關係連絡人編號').size().reset_index(name='次數')
# K_visit_df2 = K_visit_df2[(K_visit_df2['客戶關係連絡人編號'] != '') & (K_visit_df2['次數'] >= 3)]

# K_invite_all = K_invite_all[~K_invite_all['联系人手机号'].isin(K_visit_df1['联系人手机号'].drop_duplicates())]
# K_invite_all = K_invite_all[~K_invite_all['客户联系人关系'].isin(K_visit_df2['客戶關係連絡人編號'].drop_duplicates())]

# 去除已K大+已邀約
K_invite_all = K_invite_all[~K_invite_all['联系人代号'].isin(K_visit_df['联系人代号'].drop_duplicates())]
K_invite_all = K_invite_all[~K_invite_all['联系人手机号'].isin(K_visit_df['联系人手机号'].drop_duplicates())]

K_invite_all = K_invite_all.rename(columns={'accountId':'customItem70__c'})
K_invite_all = K_invite_all.rename(columns={'联系人_x':'联系人'})
# Out:
# C:\Users\11021041\AppData\Local\Temp\ipykernel_24624\233602618.py:50: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   K_visit_df['预约日期'] = pd.to_datetime(K_visit_df['预约日期'], unit='ms').dt.tz_localize('UTC').dt.tz_convert('Asia/Taipei')

# %%
'''
from K大預約表 (排除K過3次及以上的人)
'''

url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/query/xoqlScroll"
headers = {
    "Authorization": f"Bearer {ac_token}",
    "Content-Type":"application/x-www-form-urlencoded"
}
queryLocator = ''
K_visit_df = pd.DataFrame()
 
while True:
    data = {
        "xoql": '''
        SELECT 
        name,
        customItem29__c 联系人代号, 
        customItem6__c 客戶關係連絡人編號,
        customItem2__c 预约日期, 
        customItem40__c, 
        customItem9__c 联系人手机号
        FROM customEntity26__c
        ''',
        "batchCount": 2000,
        "queryLocator": queryLocator
    }
    response = requests.post(url_2, headers=headers, data=data)
    crm = response.json()
    data = pd.DataFrame(crm["data"]["records"])
    K_visit_df = pd.concat([K_visit_df, data], ignore_index=True, sort=False)
    
    if not crm['queryLocator']:
        break
    queryLocator = crm['queryLocator']

# 從大陸銷售易上線那天起所有K大場次    
K_visit_df['预约日期'] = pd.to_datetime(K_visit_df['预约日期'], unit='ms').dt.tz_localize('UTC').dt.tz_convert('Asia/Taipei')
start_date = pd.Timestamp('2023-03-02', tz='UTC') # 大陸销售易上线日期
K_visit_df['预约日期'] = pd.to_datetime(K_visit_df['预约日期'])
K_visit_df = K_visit_df[K_visit_df['预约日期'] >= start_date]

# 有舉行K大
K_visit_df['customItem40__c'] = K_visit_df['customItem40__c'].astype(str)
K_visit_df_held = K_visit_df[K_visit_df['customItem40__c'].str.contains("是")]

# 未來場次
today_date = datetime.now().strftime('%Y-%m-%d')
K_visit_df_future = K_visit_df[K_visit_df['预约日期'] >= today_date]

K_visit_df = pd.concat([K_visit_df_held, K_visit_df_future])

# 排除K過3次及以上的人
K_visit_df1 = K_visit_df.groupby('联系人手机号').size().reset_index(name='次數')
K_visit_df1 = K_visit_df1[(K_visit_df1['联系人手机号'] != '') & (K_visit_df1['次數'] >= 3)]

K_visit_df2 = K_visit_df.groupby('客戶關係連絡人編號').size().reset_index(name='次數')
K_visit_df2 = K_visit_df2[(K_visit_df2['客戶關係連絡人編號'] != '') & (K_visit_df2['次數'] >= 3)]

K_invite_all = K_invite_all[~K_invite_all['联系人手机号'].isin(K_visit_df1['联系人手机号'].drop_duplicates())]
K_invite_all = K_invite_all[~K_invite_all['客户联系人关系'].isin(K_visit_df2['客戶關係連絡人編號'].drop_duplicates())]
# Out:
# C:\Users\11021041\AppData\Local\Temp\ipykernel_24624\2429273170.py:38: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   K_visit_df['预约日期'] = pd.to_datetime(K_visit_df['预约日期'], unit='ms').dt.tz_localize('UTC').dt.tz_convert('Asia/Taipei')

# %%
'''
select from Tasks 
台湾 : entityType = '3028348436713387' or '3077984163073940 (每日K大邀約電訪交辦 or 釣魚簡訊交辦)
大陸 : entityType = '3074631761565155' (每日K大邀約電訪交辦)
'''

url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/query/xoqlScroll"
headers = {
    "Authorization": f"Bearer {ac_token}",
    "Content-Type":"application/x-www-form-urlencoded"
}
queryLocator = ''
Tasks_df = pd.DataFrame()

date_to_convert = datetime(2024, 1, 31) 
timestamp = int(date_to_convert.timestamp() * 1000)

while True:
    data = {
        "xoql": f'''
        SELECT 
        customItem42__c.contactCode__c 联系人代号, 
        customItem58__c 电访接通_无效,
        customItem8__c 执行状态
        FROM customEntity14__c
        WHERE 
            entityType = '3074631761565155' 
        AND 
            createdAt >= {timestamp}
        ''',
        "batchCount": 2000,
        "queryLocator": queryLocator
    }
    response = requests.post(url_2, headers=headers, data=data)
    crm = response.json()
    data = pd.DataFrame(crm["data"]["records"])
    Tasks_df = pd.concat([Tasks_df, data], ignore_index=True, sort=False)
    
    if not crm['queryLocator']:
        break
    queryLocator = crm['queryLocator']

Tasks_df['执行状态']= Tasks_df['执行状态'].astype(str)    
Tasks_df['电访接通_无效']= Tasks_df['电访接通_无效'].astype(str)  
Tasks_df = Tasks_df.loc[Tasks_df['执行状态'].str.contains("任务完成|进行中")]
Tasks_df1 = Tasks_df.loc[Tasks_df['电访接通_无效'].str.contains("已做开场介绍|客户拒绝邀约|未做开场介绍|客户挂断")]

K_invite_all = K_invite_all[~K_invite_all['联系人代号'].isin(Tasks_df1['联系人代号'].drop_duplicates())]

K_invite_all = K_invite_all.drop_duplicates(subset=['联系人代号'], keep='last')
K_invite_all = K_invite_all.drop_duplicates(subset=['联系人手机号'], keep='last')
K_invite_all = K_invite_all.sort_values(by='最近联系时间', na_position='first') 
K_invite_all['entityType'] = '3074631761565155'
today_date = datetime.now().strftime('%Y-%m-%d')
K_invite_all['customItem1__c'] = today_date # 台灣:期望完成日, 大陸:期望時間
K_invite_all['customItem3__c'] = 'K大邀约' + K_invite_all['联系人'] + "第一次电访"

# %%
# 經營客戶
K_invite_promote = K_invite_all.loc[K_invite_all['目标客户类型'].str.contains("经营", na=False)]
K_invite_promoting = K_invite_all.loc[K_invite_all['目标客户类型'].str.contains("开发中", na=False)]

# 非經營客戶
K_invite_non_promote = K_invite_all[~K_invite_all['联系人代号'].isin(K_invite_promote['联系人代号'].drop_duplicates())]
K_invite_non_promote = K_invite_non_promote[~K_invite_non_promote['联系人代号'].isin(K_invite_promoting['联系人代号'].drop_duplicates())]

# K_invite_promoting = K_invite_promoting.loc[K_invite_promoting['区域'].str.contains("上海", na=False)]
K_invite_non_promote = K_invite_non_promote.loc[K_invite_non_promote['区域'].str.contains("上海", na=False)]


K_invite_經營_count = K_invite_promote['联系人代号'].count()
K_invite_開發中_count = K_invite_promoting['联系人代号'].count()
K_invite_開發_count = K_invite_non_promote['联系人代号'].count()

# K_invite_經營 = (K_invite_經營_count / (K_invite_經營_count + K_invite_開發_count) )
# K_invite_開發中 = (K_invite_開發中_count / (K_invite_經營_count + K_invite_開發中_count+ K_invite_開發_count) )
# K_invite_開發 = 1 - K_invite_經營 - K_invite_開發中

K_invite_經營 = 0.7
K_invite_開發中 = 0.2
K_invite_開發 = 0.1

print(K_invite_經營)
print(K_invite_開發中)
print(K_invite_開發)
# Out:
# 0.7
# 0.2
# 0.1

# %%
'''
select from Sales list K大顧問暨電訪人員名單
customItem7__c 國家/區域
'''
url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/query/xoqlScroll"
headers = {
    "Authorization": f"Bearer {ac_token}",
    "Content-Type":"application/x-www-form-urlencoded"
}
queryLocator = ''
Sales_list = pd.DataFrame()

while True:
    data = {
        "xoql": '''
        SELECT 
        customItem2__c 电访人员, 
        customItem4__c 预估通数, 
        customItem3__c 电访人员类型
        FROM customEntity47__c
        ''',
        "batchCount": 2000,
        "queryLocator": queryLocator
    }
    response = requests.post(url_2, headers=headers, data=data)
    crm = response.json()
    data = pd.DataFrame(crm["data"]["records"])
    Sales_list = pd.concat([Sales_list, data], ignore_index=True, sort=False)
    
    if not crm['queryLocator']:
        break
    queryLocator = crm['queryLocator']

Sales_list['电访人员类型']= Sales_list['电访人员类型'].astype(str)
Sales_list = Sales_list[Sales_list['预估通数']!='']
Sales_list['预估通数']= Sales_list['预估通数'].astype(int)
Sales_list = pd.merge(Sales_list, user_df, left_on = '电访人员', right_on = 'id', how = 'left')
# Sales_list = Sales_list.loc[~Sales_list['name'].isin(['黃祿庭', '陳鵬宇', '周淑真', '葉子瑄', '黃詩婷', '林育君'])] # 改為負責智齒攔截

Sales_list = Sales_list[Sales_list['预估通数'] > 0]
Sales_list1 = Sales_list.loc[~Sales_list['电访人员类型'].str.contains("产品顾问")]
Sales_list2 = Sales_list.loc[Sales_list['电访人员类型'].str.contains("产品顾问")]
Sales_list1['经营'] = K_invite_經營 * Sales_list1['预估通数']
Sales_list1['開發中'] = K_invite_開發中 * Sales_list1['预估通数']
Sales_list1['開發'] = K_invite_開發 * Sales_list1['预估通数']
Sales_list2['经营'] = K_invite_經營 * Sales_list2['预估通数']
Sales_list2['開發中'] = K_invite_開發中 * Sales_list2['预估通数']
Sales_list2['開發'] = K_invite_開發 * Sales_list2['预估通数']
Sales_list1['经营'] = Sales_list1['经营'].astype(int)
Sales_list1['開發中'] = Sales_list1['開發中'].astype(int)
Sales_list1['開發'] = Sales_list1['開發'].astype(int)
Sales_list2['经营'] = Sales_list2['经营'].astype(int)
Sales_list2['開發中'] = Sales_list2['開發中'].astype(int)
Sales_list2['開發'] = Sales_list2['開發'].astype(int)
# Out:
# C:\Users\11021041\AppData\Local\Temp\ipykernel_24624\794047257.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_list1['经营'] = K_invite_經營 * Sales_list1['预估通数']
# C:\Users\11021041\AppData\Local\Temp\ipykernel_24624\794047257.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_list1['開發中'] = K_invite_開發中 * Sales_list1['预估通数']
# C:\Users\11021041\AppData\Local\Temp\ipykernel_24624\794047257.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_list1['開發'] = K_invite_開發 * Sales_list1['预估通数']
# C:\Users\11021041\AppData\Local\Temp\ipykernel_24624\794047257.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_list2['经营'] = K_invite_經營 * Sales_list2['预估通数']
# C:\Users\11021041\AppData\Local\Temp\ipykernel_24624\794047257.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_list2['開發中'] = K_invite_開發中 * Sales_list2['预估通数']
# C:\Users\11021041\AppData\Local\Temp\ipykernel_24624\794047257.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_list2['開發'] = K_invite_開發 * Sales_list2['预估通数']
# C:\Users\11021041\AppData\Local\Temp\ipykernel_24624\794047257.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_list1['经营'] = Sales_list1['经营'].astype(int)
# C:\Users\11021041\AppData\Local\Temp\ipykernel_24624\794047257.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_list1['開發中'] = Sales_list1['開發中'].astype(int)
# C:\Users\11021041\AppData\Local\Temp\ipykernel_24624\794047257.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_list1['開發'] = Sales_list1['開發'].astype(int)
# C:\Users\11021041\AppData\Local\Temp\ipykernel_24624\794047257.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_list2['经营'] = Sales_list2['经营'].astype(int)
# C:\Users\11021041\AppData\Local\Temp\ipykernel_24624\794047257.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_list2['開發中'] = Sales_list2['開發中'].astype(int)
# C:\Users\11021041\AppData\Local\Temp\ipykernel_24624\794047257.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_list2['開發'] = Sales_list2['開發'].astype(int)

# %%
###########接區，如當區名單不夠，隨機分配(要依照經營開發比例給名單)，同未接區邏輯
K_invite接區1 = []
for _, row in Sales_list2.iterrows():
    people = row['name']
    count = row['经营']
    
    K_invite_promote.reset_index(drop=True, inplace=True)

    count = int(count)
    
    matching_rows = K_invite_promote[K_invite_promote['电访人员'] == people].head(count)
    
    K_invite接區1.append(matching_rows)

K_invite接區1 = pd.concat(K_invite接區1)
K_invite接區1.reset_index(drop=True, inplace=True)

K_invite_promote = K_invite_promote[~K_invite_promote['联系人代号'].isin(K_invite接區1['联系人代号'].drop_duplicates())]

K_invite接區2 = []
for _, row in Sales_list2.iterrows():
    people = row['name']
    count = row['開發中']

    K_invite_promoting.reset_index(drop=True, inplace=True)
    
    count = int(count)
    
    matching_rows = K_invite_promoting[K_invite_promoting['电访人员'] == people].head(count)
    
    K_invite接區2.append(matching_rows)

K_invite接區2 = pd.concat(K_invite接區2)
K_invite接區2.reset_index(drop=True, inplace=True)

K_invite_promoting = K_invite_promoting[~K_invite_promoting['联系人代号'].isin(K_invite接區2['联系人代号'].drop_duplicates())]

K_invite接區3 = []
for _, row in Sales_list2.iterrows():
    people = row['name']
    count = row['開發']
    
    K_invite_non_promote.reset_index(drop=True, inplace=True)
    
    count = int(count)
    
    matching_rows = K_invite_non_promote[K_invite_non_promote['电访人员'] == people].head(count)
    
    K_invite接區3.append(matching_rows)

K_invite接區3 = pd.concat(K_invite接區3)
K_invite接區3.reset_index(drop=True, inplace=True)

K_invite_non_promote = K_invite_non_promote[~K_invite_non_promote['联系人代号'].isin(K_invite接區3['联系人代号'].drop_duplicates())]

K_invite_district = pd.concat([K_invite接區1,K_invite接區2, K_invite接區3])
# K_invite_district = pd.concat([K_invite接區1, K_invite接區3])
K_invite_district = K_invite_district.sample(frac=1).reset_index(drop=True)
K_invite_district = K_invite_district.drop_duplicates(subset=['联系人代号'], keep='last')

K_invite_district = pd.merge(K_invite_district, user_df, left_on = '电访人员', right_on = 'name', how = 'left')
K_invite_district = pd.merge(K_invite_district, user_df, left_on = '区域', right_on = 'name', how = 'left')

K_invite_district = K_invite_district.drop(['电访人员'],axis=1)
K_invite_district = K_invite_district.drop(['dimDepart'],axis=1)
K_invite_district = K_invite_district.drop(['dimDepart_y'],axis=1)
K_invite_district = K_invite_district.rename(columns={'id_x':'电访人员', 'dimDepart_x' : 'dimDepart', 'id_y':'ownerId'})

K_invite_district['电访人员'].value_counts()
# Out:
# 电访人员
# 2644467588813632    150
# 2644467588813655    150
# Name: count, dtype: int64

# %%
K_invite_promote
# Out:
#               联系人        联系人代号       公司代号_x       联系人手机号                 修改日期  \
# 770           徐卓栋  CCO00389154  CAC00067353  13017706550  2024-07-04 00:34:28
# 771           陈忠亮  CCO00127517  CAC00060799  13893203023  2024-07-03 07:56:08
# 772           郭森斌  CCO00260524  CAC00162380  17796139378  2024-07-03 07:56:08
# 773           付晓鸥  CCO00073628  CAC00095196  15928804877  2024-08-07 06:58:42
# 774           袁建R  CCO00202966  CAC00179858  13576278482  2024-07-03 08:00:30
# ...           ...          ...          ...          ...                  ...
# 8609           漆芬  CCO00414462  CAC00175678  13536961630  2024-12-17 00:10:49
# 8610       韩改涛(R)  CCO00332551  CAC00173053  13784337040  2024-12-17 00:10:49
# 8611  程晓明(R-设计总监)  CCO00354014  CAC00188765  13325161387  2024-12-17 00:10:49
# 8612           潘斌  CCO00588069  CAC00174431  13333870044  2024-12-17 00:10:49
# 8613          李春旺  CCO00364783  CAC00051746  15034113337  2024-12-17 00:10:49
#
#              客户联系人关系_x 联系人代号_舊_x              微信号码             职务类别 有效_总_x  \
# 770   2836096979965406    869436               NaN          ['设计师']     有效
# 771   2836112294942242    374278  306051617@qq.com          ['设计师']     有效
# 772   2836125256488461    666204               NaN   ['设计助理/深化/绘图']     有效
# 773   2836150827767325    200387               NaN          ['设计师']     有效
# 774   2836108233266730    558574               NaN          ['设计师']     有效
# ...                ...       ...               ...              ...    ...
# 8609  2836108106487318    930684               NaN          ['设计师']     有效
# 8610  2836147426956744    786854              同手机号  ['负责人/董事长/总经理']     有效
# 8611  2836103490131474    790307               NaN         ['设计总监']     有效
# 8612  3008149654345199       NaN               NaN  ['负责人/董事长/总经理']     有效
# 8613  2836117607896587    850045               NaN  ['负责人/董事长/总经理']     有效
#
#       ...     关系状态_y         dimDepart 联系人代号_舊_y 有效_总_y 经销商签约系列_y      区域  \
# 770   ...  [在职-主要公司]  2794759030478288    869436     有效       nan   杭州、绍兴
# 771   ...  [在职-主要公司]  2794747741885967    374278     有效       nan      西安
# 772   ...  [在职-主要公司]  2794746540529195    666204     有效       nan   中山、珠海
# 773   ...  [在职-主要公司]  2794748093863381    200387     有效       nan      成都
# 774   ...  [在职-主要公司]  2794749524432335    558574     有效       nan      南昌
# ...   ...        ...               ...       ...    ...       ...     ...
# 8609  ...  [在职-主要公司]  2794748093863381    930684     有效       nan      成都
# 8610  ...  [在职-主要公司]  2794757704390185    786854     有效       nan  石家庄、太原
# 8611  ...  [在职-主要公司]  2794757854221788    790307     有效       nan   青岛、烟台
# 8612  ...  [在职-主要公司]  2794759388501504               有效       nan      郑州
# 8613  ...  [在职-主要公司]  2794757704390185    850045     有效       nan  石家庄、太原
#
#      电访人员        entityType customItem1__c        customItem3__c
# 770    楼俊  3074631761565155     2025-03-14          K大邀约徐卓栋第一次电访
# 771    楼俊  3074631761565155     2025-03-14          K大邀约陈忠亮第一次电访
# 772   李静静  3074631761565155     2025-03-14          K大邀约郭森斌第一次电访
# 773    楼俊  3074631761565155     2025-03-14          K大邀约付晓鸥第一次电访
# 774    楼俊  3074631761565155     2025-03-14          K大邀约袁建R第一次电访
# ...   ...               ...            ...                   ...
# 8609   楼俊  3074631761565155     2025-03-14           K大邀约漆芬第一次电访
# 8610   楼俊  3074631761565155     2025-03-14       K大邀约韩改涛(R)第一次电访
# 8611   楼俊  3074631761565155     2025-03-14  K大邀约程晓明(R-设计总监)第一次电访
# 8612   楼俊  3074631761565155     2025-03-14           K大邀约潘斌第一次电访
# 8613   楼俊  3074631761565155     2025-03-14          K大邀约李春旺第一次电访
#
# [7844 rows x 53 columns]

# %%
#########未接區
invited_people1 = []

for index, row in Sales_list1.iterrows():
    person = row['电访人员']  # Assuming 'person' is the column name
    count = row['经营']  # Assuming 'count' is the column name

    # Extend the invited_people list with 'person' repeated 'count' times
    if not pd.isna(count):
        invited_people1.extend([person] * int(count))
invited_people1 = pd.DataFrame({'客服主任': invited_people1})

invited_people2 = []

for index, row in Sales_list1.iterrows():
    person = row['电访人员']  # Assuming 'person' is the column name
    count = row['開發中']  # Assuming 'count' is the column name

    # Extend the invited_people list with 'person' repeated 'count' times
    if not pd.isna(count):
        invited_people2.extend([person] * int(count))
invited_people2 = pd.DataFrame({'客服主任': invited_people2})

invited_people3 = []

for index, row in Sales_list1.iterrows():
    person = row['电访人员']  # Assuming 'person' is the column name
    count = row['開發']  # Assuming 'count' is the column name

    # Extend the invited_people list with 'person' repeated 'count' times
    if not pd.isna(count):
        invited_people3.extend([person] * int(count))
invited_people3 = pd.DataFrame({'客服主任': invited_people3})


invited_people1.reset_index(drop=True, inplace=True)
invited_people2.reset_index(drop=True, inplace=True)
invited_people3.reset_index(drop=True, inplace=True)
K_invite_promote.reset_index(drop=True, inplace=True)
K_invite_promoting.reset_index(drop=True, inplace=True)
K_invite_non_promote.reset_index(drop=True, inplace=True)

# filtered_K_invite_promote = K_invite_promote[~K_invite_promote['区域'].isin(['泉州', '厦门', '西安', '南宁', '昆明、贵阳', '重庆', '成都', '无锡', '苏州'])]
# filtered_K_invite_promote.reset_index(drop=True, inplace=True)  
K_invite未接1 = pd.concat([K_invite_promote,invited_people1],axis=1)
K_invite未接1.reset_index(drop=True, inplace=True)  
K_invite未接1 = K_invite未接1.drop(['电访人员'],axis=1)
K_invite未接1 = K_invite未接1.rename(columns={'客服主任':'电访人员'})
K_invite未接1 = K_invite未接1[K_invite未接1['电访人员'].notnull()]
K_invite未接1 = K_invite未接1[K_invite未接1['联系人代号'].notnull()]
K_invite_promote = K_invite_promote[~K_invite_promote['联系人代号'].isin(K_invite未接1['联系人代号'].drop_duplicates())]

# filtered_K_invite_promoting = K_invite_promoting[~K_invite_promoting['区域'].isin(['泉州', '厦门', '西安', '南宁', '昆明、贵阳', '重庆', '成都', '无锡', '苏州'])]
# filtered_K_invite_promoting.reset_index(drop=True, inplace=True)  
K_invite未接2 = pd.concat([K_invite_promoting,invited_people2],axis=1)
K_invite未接2.reset_index(drop=True, inplace=True)  
K_invite未接2 = K_invite未接2.drop(['电访人员'],axis=1)
K_invite未接2 = K_invite未接2.rename(columns={'客服主任':'电访人员'})
K_invite未接2 = K_invite未接2[K_invite未接2['电访人员'].notnull()]
K_invite未接2 = K_invite未接2[K_invite未接2['联系人代号'].notnull()]
K_invite_promoting = K_invite_promoting[~K_invite_promoting['联系人代号'].isin(K_invite未接2['联系人代号'].drop_duplicates())]

# filtered_K_invite_non_promote = K_invite_non_promote[~K_invite_non_promote['区域'].isin(['泉州', '厦门', '西安', '南宁', '昆明、贵阳', '重庆', '成都', '无锡', '苏州'])]
# filtered_K_invite_non_promote.reset_index(drop=True, inplace=True)  
K_invite未接3 = pd.concat([K_invite_non_promote,invited_people3],axis=1)
K_invite未接3.reset_index(drop=True, inplace=True)  
K_invite未接3 = K_invite未接3.drop(['电访人员'],axis=1)
K_invite未接3 = K_invite未接3.rename(columns={'客服主任':'电访人员'})
K_invite未接3 = K_invite未接3[K_invite未接3['电访人员'].notnull()]
K_invite未接3 = K_invite未接3[K_invite未接3['联系人代号'].notnull()]
K_invite_non_promote = K_invite_non_promote[~K_invite_non_promote['联系人代号'].isin(K_invite未接3['联系人代号'].drop_duplicates())]

K_invite_non_district = pd.concat([K_invite未接1,K_invite未接2,K_invite未接3])
# K_invite_non_district = pd.concat([K_invite未接1, K_invite未接3])
K_invite_non_district = K_invite_non_district.sample(frac=1).reset_index(drop=True)
K_invite_non_district = K_invite_non_district.drop_duplicates(subset=['联系人代号'], keep='last')

K_invite_non_district = pd.merge(K_invite_non_district, user_df, left_on = '区域', right_on = 'name', how = 'left')
K_invite_non_district = K_invite_non_district.drop(['dimDepart_y'],axis=1)
K_invite_non_district = K_invite_non_district.rename(columns={'id':'ownerId', 'dimDepart_x' : 'dimDepart'})

K_invite_non_district['电访人员'].value_counts()
# Out:
# 电访人员
# 3708943322109405    300
# 3715951347749679    300
# 3321172257968944    300
# 2709514453554019    200
# Name: count, dtype: int64

# %%
K_invite_list = pd.concat([K_invite_non_district, K_invite_district])

K_invite_list['customItem11__c'] = K_invite_list['customItem70__c']

K_invite_list = K_invite_list.drop_duplicates(subset=['联系人代号'], keep='last')

K_invite_list.rename(columns={'客户联系人关系':'customItem42__c',
                              '电访人员':'customItem10__c'}, inplace=True)

K_invite_task = K_invite_list[['customItem42__c',
                            'entityType',
                            'customItem1__c',
                            'customItem3__c',
                            'customItem10__c',
                            'dimDepart',
                            'customItem70__c',
                            'customItem11__c',
                            'ownerId']]

K_invite_task = K_invite_task.astype(str)


K_invite_task
# Out:
#       customItem42__c        entityType customItem1__c  customItem3__c  \
# 0    2836125150959053  3074631761565155     2025-03-14    K大邀约徐梦晗第一次电访
# 1    2836120532620758  3074631761565155     2025-03-14   K大邀约张老师R第一次电访
# 2    2836117607945679  3074631761565155     2025-03-14  K大邀约郝总(R)第一次电访
# 3    2836117328500258  3074631761565155     2025-03-14    K大邀约全秀明第一次电访
# 4    2836124834764321  3074631761565155     2025-03-14    K大邀约孙燕S第一次电访
# ..                ...               ...            ...             ...
# 295  2836133963372013  3074631761565155     2025-03-14    K大邀约任政宇第一次电访
# 296  3124653853283782  3074631761565155     2025-03-14    K大邀约耿鑫R第一次电访
# 297  2836108294936101  3074631761565155     2025-03-14    K大邀约陈扬R第一次电访
# 298  2836108882548187  3074631761565155     2025-03-14    K大邀约许旭亮第一次电访
# 299  2836097272862234  3074631761565155     2025-03-14    K大邀约刘远芬第一次电访
#
#       customItem10__c         dimDepart   customItem70__c   customItem11__c  \
# 0    3708943322109405  2794749524432335  2756225367479842  2756225367479842
# 1    3708943322109405  2794756591310275  2756233668285891  2756233668285891
# 2    3715951347749679  2794757704390185  2756233767704010  2756233767704010
# 3    3715951347749679  2794749524432335  2756223597712843  2756223597712843
# 4    2709514453554019  2794754684769777  2756242613228992  2756242613228992
# ..                ...               ...               ...               ...
# 295  2644467588813632  2794758458791434  2756231275484616  2756231275484616
# 296  2644467588813632  2794755360101904  2668687961199378  2668687961199378
# 297  2644467588813632  3389236964070874  2668687772275524  2668687772275524
# 298  2644467588813655  2794746540529182  2756232041764363  2756232041764363
# 299  2644467588813655  2794516231657004  2756224303142442  2756224303142442
#
#               ownerId
# 0    2832606161163810
# 1    2928327405966876
# 2    2957373279327701
# 3    2832606161163810
# 4    2928325664936716
# ..                ...
# 295  2957372554761024
# 296  2957360699085671
# 297  3389226568914396
# 298  2957481515045703
# 299  2957472544494445
#
# [1400 rows x 9 columns]

# %%
##########補名單

# K_invite_add_all = pd.read_excel('K_invite_add_all.xlsx')
K_invite_add_all = pd.concat([K_invite_promote, K_invite_promoting, K_invite_non_promote])
K_invite_add_all = K_invite_add_all[~K_invite_add_all['联系人代号'].isin(K_invite_list['联系人代号'].drop_duplicates())]
K_invite_add_all.to_excel('K_invite_add_all.xlsx', index=False)

# %%
Sales = "张超"

K_invite_add_all = K_invite_add_all.sample(frac=1).reset_index(drop=True)

# # 根據區域提供名單
# K_invite_add_all = K_invite_add_all[~K_invite_add_all['区域'].isna()]
# K_invite_add_all = K_invite_add_all[K_invite_add_all['区域'].str.contains('杭州')]

# 補名單數量
K_invite_add = K_invite_add_all[:300]
K_invite_add_all = K_invite_add_all[~K_invite_add_all['联系人代号'].isin(K_invite_add['联系人代号'].drop_duplicates())]

K_invite_add.loc[K_invite_add['电访人员'] != '', '电访人员'] = Sales

K_invite_task = pd.merge(K_invite_add, user_df, left_on = '电访人员', right_on = 'name', how = 'left')
K_invite_task = pd.merge(K_invite_task, user_df, left_on = '区域', right_on = 'name', how = 'left')


K_invite_task = K_invite_task.drop(['电访人员'],axis=1)
K_invite_task = K_invite_task.drop(['dimDepart'],axis=1)
K_invite_task = K_invite_task.rename(columns={'id_x':'电访人员'})

K_invite_task.rename(columns={'电访人员': 'customItem10__c',
                              '客户联系人关系':'customItem42__c',
                              'dimDepart_x':'dimDepart',
                              'id_y':'ownerId'}, inplace=True)

K_invite_task['customItem11__c'] = K_invite_task['customItem70__c']

K_invite_task = K_invite_task[['customItem42__c',
                               'entityType',
                               'customItem1__c',
                               'customItem3__c',
                               'customItem10__c',
                               'dimDepart',
                               'customItem70__c',
                               'customItem11__c',
                               'ownerId']]

K_invite_task = K_invite_task.astype(str)

K_invite_task

# %%
'''
ask bulk id
'''
url_2 = "https://api-scrm.xiaoshouyi.com/rest/bulk/v2/job"

headers = {
    "Authorization": f"Bearer {ac_token}",
    "Content-Type":"application/json"
}

data = {
     "data": {
        "operation": "insert",####################################################################3
        "object": "customEntity14__c",
        "execOption": ["CHECK_RULE", "CHECK_DUPLICATE"]
    }
    
}

response = requests.post(url_2, headers = headers, json = data)
test = response.json()
bulk_id = test["result"]["id"]
print(bulk_id)
# Out:
# e9fa96a8caa871e0ab36de8779d0f0cf3f1f94c763c14c118d1b2c2d907fe2ce

# %%
'''
insert to crm if dataframe over 5000
'''
batch_size = 5000

# Calculate the number of batches
num_batches = (len(K_invite_task) + batch_size - 1) // batch_size

# Initialize a list to store responses
all_responses = []

# Initialize an index to keep track of the current batch
current_batch_index = 0

# While there are more batches to process
while current_batch_index < num_batches:
    start_index = current_batch_index * batch_size
    end_index = (current_batch_index + 1) * batch_size
    current_batch_df = K_invite_task.iloc[start_index:end_index]
    json_data = current_batch_df.to_dict(orient='records')
    
    url_2 = "https://api-scrm.xiaoshouyi.com/rest/bulk/v2/batch"
    headers = {
        "Authorization": f"Bearer {ac_token}",
        "Content-Type":"application/json"
    }
    data = {
        "data": {
            "jobId": f"{bulk_id}",
            "datas": json_data
        }
    }
    response = requests.post(url_2, headers=headers, json=data)
    all_responses.append(response)
    current_batch_index += 1
for response in all_responses:
    pass

# %%
'''
select from Tasks 
'''
url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/query/xoqlScroll"

headers = {
    "Authorization": f"Bearer {ac_token}",
    "Content-Type":"application/x-www-form-urlencoded"
}

queryLocator = ''

Tasks_df = pd.DataFrame()

while True:
    data = {
        "xoql": '''
        SELECT 
        id,
        name, 
        customItem10__c, 
        customItem3__c, 
        approvalStatus
        FROM customEntity14__c 
        WHERE 
            entityType = '3074631761565155'
        AND
            createdBy = '3052177351988706'
        ''',
        "batchCount": 2000,
        "queryLocator": queryLocator
    }
    response = requests.post(url_2, headers=headers, data=data)
    crm = response.json()
    data = pd.DataFrame(crm["data"]["records"])
    Tasks_df = pd.concat([Tasks_df, data], ignore_index=True, sort=False)
    
    if not crm['queryLocator']:
        break
    queryLocator = crm['queryLocator']
    
Tasks_df['approvalStatus']= Tasks_df['approvalStatus'].astype(str)
Tasks_df = Tasks_df.loc[Tasks_df['approvalStatus'].str.contains("待提交")] 

Tasks_df
# Out:
# Empty DataFrame
# Columns: [id, name, customItem10__c, customItem3__c, approvalStatus]
# Index: []

# %%
'''
submit_task
'''

status_url = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/creekflow/task/actions/preProcessor"
task_url = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/creekflow/task"
headers = {
        "Authorization": f"Bearer {ac_token}",
        "Content-Type": "application/json"
    }

def preProcessor(process_ID):
    status_body = {
        "data": {
            "action": "submit",
            "entityApiKey": "customEntity14__c",
            "dataId": process_ID }}

    response = requests.post(status_url, headers=headers, json=status_body)
    crm_json = response.json()['data']
    return crm_json

tasks_df_last_row = Tasks_df.iloc[-1]
approval_status = preProcessor(tasks_df_last_row['id'])

def submit_task(row):
    data_id = row['id']
    task_id = row['customItem10__c']
    url_2 = "https://api-scrm.xiaoshouyi.com/rest/data/v2.0/creekflow/task"
    headers = {
        "Authorization": f"Bearer {ac_token}",
        "Content-Type": "application/json"
    }

    data = {
        "data": {
            "action": "submit",
            "entityApiKey": "customEntity14__c",
            "dataId": data_id,
            "procdefId": approval_status['procdefId'],
            "nextTaskDefKey": approval_status['nextTaskDefKey'],
            "nextAssignees": [task_id],
            "ccs": [task_id]  
        }
    }

    response = requests.post(url_2, headers=headers, json=data)
    result = response.json()
    print(f"Response for dataId {data_id}: {result}")

# Assuming data_ids is your DataFrame
data_ids_df = Tasks_df[['id', 'customItem10__c']]

# Create a thread for each row in the DataFrame
threads = []
for index, row in data_ids_df.iterrows():
    thread = threading.Thread(target=submit_task, args=(row,))
    threads.append(thread)
    thread.start()
    time.sleep(0.08)

# Wait for all threads to finish
for thread in threads:
    thread.join()
# Out:
# Response for dataId 3721576209355562: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576209355563: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576209355564: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576209355565: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576209355566: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576209355567: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576209355568: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576209355569: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990617: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990618: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990619: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990620: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990621: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990622: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990623: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990624: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990625: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990626: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990627: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990628: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990629: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990630: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990631: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990632: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990633: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990634: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990635: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990636: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990637: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990638: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990639: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990640: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576358990641: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696137: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696138: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696139: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696140: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696141: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696142: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696143: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696144: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696145: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696146: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696147: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696148: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696149: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696150: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696151: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696153: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696152: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696154: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696155: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696156: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696157: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696158: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696160: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696159: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696161: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696162: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696163: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696164: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696165: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696166: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696167: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696168: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696169: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696170: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696171: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696172: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696173: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696174: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696175: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696176: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721576983696177: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721159: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721160: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721161: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721163: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721164: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721162: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721165: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721166: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721167: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721168: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721169: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721170: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721171: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721172: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721173: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721174: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721176: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721175: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721177: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721178: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721179: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721180: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721181: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721182: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721183: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721184: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721185: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721186: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721187: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721188: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721189: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721190: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721191: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721192: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721193: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721194: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721195: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721196: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721197: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721198: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721199: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721200: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577224721201: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479424: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479425: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479426: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479427: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479428: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479429: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479430: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479431: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479432: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479433: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479434: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479435: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479436: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479437: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479438: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479439: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479440: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479441: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479442: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479443: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479444: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479445: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479446: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479447: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479448: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479449: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479450: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479451: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479452: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479453: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479454: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479455: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479456: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479457: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479458: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479459: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479460: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479461: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479462: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479463: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479464: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479465: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479466: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479467: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479468: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479469: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479470: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479471: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479472: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332479473: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740864: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740865: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740866: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740867: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740869: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740868: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740870: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740871: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740872: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740873: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740874: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740875: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740876: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740877: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740878: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740879: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740880: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740881: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740882: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740883: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740884: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740885: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740886: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740887: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740888: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740890: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740891: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740889: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740892: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740893: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740894: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740895: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740896: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740897: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740898: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740899: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740901: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740900: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740902: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740903: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740904: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740905: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740906: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740909: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740907: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740908: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740910: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740911: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740912: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577332740913: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233088: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233089: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233090: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233091: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233092: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233093: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233094: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233095: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233096: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233097: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233098: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233099: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233100: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233101: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233102: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233103: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233104: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233105: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233106: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233107: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233108: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233109: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233110: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233111: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233112: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233113: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233114: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233115: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233116: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233117: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233118: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233119: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233120: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233121: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233122: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233123: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233124: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233125: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233126: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233127: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233128: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233129: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233130: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233131: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233132: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233133: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233134: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233135: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233136: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333233137: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396224: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396225: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396226: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396227: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396228: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396229: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396230: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396231: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396232: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396233: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396234: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396235: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396236: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396238: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396239: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396237: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396240: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396241: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396242: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396243: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396244: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396245: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396246: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396247: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396248: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396249: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396250: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396251: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396252: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396253: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396254: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396255: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396256: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396257: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396258: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396259: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396260: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396261: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396262: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396263: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396264: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396265: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396266: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396267: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396269: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396270: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396268: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396271: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396272: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333396273: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904128: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904129: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904130: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904131: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904132: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904133: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904134: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904135: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904136: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904137: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904138: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904139: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904140: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904141: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904142: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904143: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904144: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904145: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904146: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904147: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904148: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904149: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904150: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904151: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904152: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904153: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904154: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904155: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904156: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904157: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904158: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904159: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904160: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904161: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904162: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904163: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904164: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904165: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904166: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904167: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904168: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904169: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904170: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904171: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904172: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904173: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904174: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904175: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904176: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577333904177: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232512: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232513: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232514: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232515: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232516: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232517: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232518: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232519: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232520: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232521: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232522: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232523: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232524: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232525: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232526: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232528: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232527: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232529: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232530: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232531: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232532: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232533: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232534: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232535: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232536: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232538: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232539: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232537: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232540: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232541: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232542: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232543: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232544: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232545: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232546: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232547: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232548: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232549: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232550: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232551: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232552: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232553: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232554: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232555: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232556: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232557: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232558: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232559: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232560: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232561: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232562: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232563: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232564: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232565: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232567: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232566: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232568: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232569: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232570: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232571: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232572: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232573: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232574: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334232575: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248896: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248897: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248898: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248899: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248900: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248901: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248902: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248903: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248904: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248905: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248906: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248907: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248908: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248909: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248910: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248911: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248912: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248913: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248914: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248915: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248916: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248917: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248918: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248919: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248920: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248921: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248922: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248923: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248925: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248926: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248927: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248924: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248928: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248929: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248930: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248931: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248932: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248933: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248934: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248935: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248936: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248937: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248938: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248939: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248940: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248941: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248942: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248943: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577334248944: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# ...
# Response for dataId 3721577387758363: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577387758364: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577387758365: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577387758366: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577387758367: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577387758368: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577387758378: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577387758375: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577387758376: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577387758379: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577387758377: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577387758381: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577387758382: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577387758380: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577387758383: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577387758384: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577387758385: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626816: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626817: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626818: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626820: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626819: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626821: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626822: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626824: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626823: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626825: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626826: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626827: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626828: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626829: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626831: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626830: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626832: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626833: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626834: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626843: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626844: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626846: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626845: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626847: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626848: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626849: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626850: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626851: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626852: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626853: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626854: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626855: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626856: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626857: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626858: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626859: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626860: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626861: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626862: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626863: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626864: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577389626865: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391166208: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391166210: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391166209: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391166211: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391166212: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391166213: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391166214: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391166221: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}Response for dataId 3721577391166222: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
#
# Response for dataId 3721577391166223: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391166224: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391166225: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391166228: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391166229: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391166227: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391166230: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391166226: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936256: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936257: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936258: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936259: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936260: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936261: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936262: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936264: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936263: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936265: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936266: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936267: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936268: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936269: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936278: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936277: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936279: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936280: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936281: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936282: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936283: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936284: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936285: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936286: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936287: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936288: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936289: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936290: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936292: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}Response for dataId 3721577391936291: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
#
# Response for dataId 3721577391936293: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936294: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936295: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936296: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936297: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936298: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936299: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936301: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936300: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936302: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936303: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936304: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577391936305: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378752: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378760: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378761: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378762: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378763: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378764: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378765: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378766: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378767: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378768: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378769: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378770: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378771: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378772: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378773: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378774: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378775: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378777: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378776: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378778: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378780: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378781: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378782: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378783: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378784: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378785: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378786: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378787: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378789: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378788: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378790: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378797: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378798: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378799: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378800: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577393378801: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577396392755: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577396392754: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577396392758: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577396392756: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
# Response for dataId 3721577396392757: {'code': '200', 'msg': 'OK', 'data': None, 'errorInfo': None}
